# %%
# %pip install requests beautifulsoup4 lxml python-dateutil feedparser
# Out:
# Requirement already satisfied: requests in d:\work\big_data\.venv\lib\site-packages (2.32.5)
# Requirement already satisfied: beautifulsoup4 in d:\work\big_data\.venv\lib\site-packages (4.14.3)
# Requirement already satisfied: lxml in d:\work\big_data\.venv\lib\site-packages (6.0.2)
# Requirement already satisfied: python-dateutil in d:\work\big_data\.venv\lib\site-packages (2.9.0.post0)
# Collecting feedparser
#   Using cached feedparser-6.0.12-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\work\big_data\.venv\lib\site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\work\big_data\.venv\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\work\big_data\.venv\lib\site-packages (from requests) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in d:\work\big_data\.venv\lib\site-packages (from requests) (2025.11.12)
# Requirement already satisfied: soupsieve>=1.6.1 in d:\work\big_data\.venv\lib\site-packages (from beautifulsoup4) (2.8.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\work\big_data\.venv\lib\site-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: six>=1.5 in d:\work\big_data\.venv\lib\site-packages (from python-dateutil) (1.17.0)
# Collecting sgmllib3k (from feedparser)
#   Using cached sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Using cached feedparser-6.0.12-py3-none-any.whl (81 kB)
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (pyproject.toml): started
#   Building wheel for sgmllib3k (pyproject.toml): finished with status 'done'
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6104 sha256=03c8105bf184a641c4c6a04fa83f3f06ec5cbbd3348b1f8d66ac149bc2d9c17e
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\f0\69\93\a47e9d621be168e9e33c7ce60524393c0b92ae83cf6c6e89c5
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
#
#    ---------------------------------------- 2/2 [feedparser]
#
# Successfully installed feedparser-6.0.12 sgmllib3k-1.0.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 26.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import csv
import os
import re
import time
import hashlib
from datetime import datetime, timezone, timedelta
from typing import Optional, Dict, Any, List, Set, Tuple

import requests
import feedparser
from bs4 import BeautifulSoup
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

VN_TZ = timezone(timedelta(hours=7))

# ================== CONFIG ==================
# Danh sách các RSS feeds từ các báo Việt Nam
RSS_FEEDS = [
    # VnExpress RSS (15 feeds)
    "https://vnexpress.net/rss/tin-moi-nhat.rss",
    "https://vnexpress.net/rss/thoi-su.rss",
    "https://vnexpress.net/rss/the-gioi.rss",
    "https://vnexpress.net/rss/kinh-doanh.rss",
    "https://vnexpress.net/rss/giai-tri.rss",
    "https://vnexpress.net/rss/the-thao.rss",
    "https://vnexpress.net/rss/phap-luat.rss",
    "https://vnexpress.net/rss/giao-duc.rss",
    "https://vnexpress.net/rss/suc-khoe.rss",
    "https://vnexpress.net/rss/gia-dinh.rss",
    "https://vnexpress.net/rss/du-lich.rss",
    "https://vnexpress.net/rss/khoa-hoc.rss",
    "https://vnexpress.net/rss/so-hoa.rss",
    "https://vnexpress.net/rss/oto-xe-may.rss",
    "https://vnexpress.net/rss/y-kien.rss",
    
    # Dân Trí RSS (10 feeds)
    "https://dantri.com.vn/rss/trang-chu.rss",
    "https://dantri.com.vn/rss/xa-hoi.rss",
    "https://dantri.com.vn/rss/the-gioi.rss",
    "https://dantri.com.vn/rss/kinh-doanh.rss",
    "https://dantri.com.vn/rss/the-thao.rss",
    "https://dantri.com.vn/rss/giai-tri.rss",
    "https://dantri.com.vn/rss/giao-duc.rss",
    "https://dantri.com.vn/rss/suc-khoe.rss",
    "https://dantri.com.vn/rss/du-lich.rss",
    "https://dantri.com.vn/rss/o-to-xe-may.rss",
    
    # Tuổi Trẻ RSS (9 feeds)
    "https://tuoitre.vn/rss/tin-moi-nhat.rss",
    "https://tuoitre.vn/rss/thoi-su.rss",
    "https://tuoitre.vn/rss/the-gioi.rss",
    "https://kienthuc.net.vn/rss/quan-su-359.rss",
    "https://kienthuc.net.vn/rss/giai-tri-365.rss",
]

# Crawl tất cả bài viết từ RSS feeds
END_DATE = "2026-01-15"  # YYYY-MM-DD - chỉ lấy bài >= ngày này

CSV_PATH = "rss_feed_articles_v2.csv"

# Có fetch full content từ URL gốc không (chậm hơn nhưng đầy đủ hơn)
FETCH_FULL_CONTENT = True

TIMEOUT = 25
REQUEST_DELAY_BASE = 0.25
HEADERS = {
    "User-Agent": "Mozilla/5.0 (compatible; RSSCrawler/1.0)",
    "Accept": "application/rss+xml, application/xml, text/xml, */*",
}
# ===========================================

CSV_HEADER = [
    "id",
    "title",
    "published_at",        # ISO UTC
    "source.name",
    "url",
    "language",
    "category.primary",
    "keywords",
    "entities",
    "content.text",
]

SOURCE_NAME = "RSS_Feed"
DEFAULT_LANGUAGE = "vi"
DEBUG = False

# ----- HTTP session with retry -----
session = requests.Session()
session.headers.update(HEADERS)

retry = Retry(
    total=6,
    connect=6,
    read=6,
    backoff_factor=0.6,
    status_forcelist=[429, 500, 502, 503, 504],
    allowed_methods=["GET", "HEAD"],
    respect_retry_after_header=True,
    raise_on_status=False,
)
adapter = HTTPAdapter(max_retries=retry, pool_connections=50, pool_maxsize=50)
session.mount("http://", adapter)
session.mount("https://", adapter)


def log(msg: str):
    if DEBUG:
        print(msg)


def polite_sleep():
    time.sleep(REQUEST_DELAY_BASE)


def md5_id(text: str) -> str:
    return hashlib.md5(text.encode("utf-8")).hexdigest()


def fetch_text(url: str) -> str:
    r = session.get(url, timeout=TIMEOUT, allow_redirects=True)
    r.raise_for_status()
    return r.text


def ensure_csv_header(csv_path: str):
    if not os.path.exists(csv_path) or os.path.getsize(csv_path) == 0:
        with open(csv_path, "w", encoding="utf-8", newline="") as f:
            csv.writer(f).writerow(CSV_HEADER)


def load_seen_from_csv(csv_path: str) -> Tuple[Set[str], Set[str]]:
    seen_urls, seen_ids = set(), set()
    if not os.path.exists(csv_path):
        return seen_urls, seen_ids
    try:
        with open(csv_path, "r", encoding="utf-8", newline="") as f:
            r = csv.reader(f)
            header = next(r, None)
            if not header:
                return seen_urls, seen_ids
            id_idx = header.index("id") if "id" in header else 0
            url_idx = header.index("url") if "url" in header else 4
            for row in r:
                if len(row) > url_idx:
                    u = row[url_idx].strip()
                    if u:
                        seen_urls.add(u)
                if len(row) > id_idx:
                    i = row[id_idx].strip()
                    if i:
                        seen_ids.add(i)
    except Exception:
        pass
    return seen_urls, seen_ids


def append_row(csv_path: str, row: Dict[str, Any]):
    with open(csv_path, "a", encoding="utf-8", newline="") as f:
        w = csv.writer(f)
        w.writerow([row.get(k, "") for k in CSV_HEADER])
        f.flush()


def iso_to_local_date(iso_utc: str) -> Optional[str]:
    if not iso_utc:
        return None
    try:
        dt = datetime.fromisoformat(iso_utc.replace("Z", "+00:00"))
        if dt.tzinfo is None:
            dt = dt.replace(tzinfo=timezone.utc)
        return dt.astimezone(VN_TZ).date().isoformat()
    except Exception:
        return None


def parse_rss_date(date_str: str) -> Optional[str]:
    """
    Parse RSS date format to ISO UTC
    RSS thường dùng RFC 2822 hoặc ISO format
    """
    if not date_str:
        return None
    
    try:
        # feedparser tự động parse date
        from email.utils import parsedate_to_datetime
        dt = parsedate_to_datetime(date_str)
        return dt.astimezone(timezone.utc).isoformat()
    except Exception:
        pass
    
    # Thử ISO format
    try:
        dt = datetime.fromisoformat(date_str.replace("Z", "+00:00"))
        if dt.tzinfo is None:
            dt = dt.replace(tzinfo=VN_TZ)
        return dt.astimezone(timezone.utc).isoformat()
    except Exception:
        pass
    
    return None


def extract_category_from_url(url: str) -> Optional[str]:
    """Trích xuất category từ URL pattern"""
    from urllib.parse import urlparse
    
    # Mapping các patterns phổ biến
    category_map = {
        'thoi-su': 'Thời sự',
        'the-gioi': 'Thế giới', 
        'xa-hoi': 'Xã hội',
        'kinh-doanh': 'Kinh doanh',
        'giai-tri': 'Giải trí',
        'the-thao': 'Thể thao',
        'phap-luat': 'Pháp luật',
        'giao-duc': 'Giáo dục',
        'suc-khoe': 'Sức khỏe',
        'gia-dinh': 'Gia đình',
        'du-lich': 'Du lịch',
        'khoa-hoc': 'Khoa học',
        'so-hoa': 'Số hóa',
        'cong-nghe': 'Công nghệ',
        'oto-xe-may': 'Ôtô-Xe máy',
        'doi-song': 'Đời sống',
        'van-hoa': 'Văn hóa',
        'tin-tuc': 'Tin tức',
        'video': 'Video',
    }
    
    try:
        parsed = urlparse(url)
        path_parts = [p for p in parsed.path.split('/') if p]
        
        # Tìm category trong các phần của URL (chỉ xét 2 phần đầu)
        for part in path_parts[:2]:
            for pattern, category in category_map.items():
                if pattern in part:
                    return category
    except Exception:
        pass
    
    return None


def extract_keywords_from_entry(entry: Any, url: str) -> List[str]:
    """Trích xuất keywords từ RSS entry và URL"""
    keywords = []
    
    # 1. Lấy từ tags RSS (Dân Trí, Tuổi Trẻ có field này)
    if 'tags' in entry and entry.tags:
        for tag in entry.tags:
            term = tag.get('term', '').strip()
            if term and term not in keywords:
                keywords.append(term)
    
    # 2. Lấy từ category field (nếu không có trong tags)
    if 'category' in entry and entry.category:
        cat = entry.category.strip()
        if cat and cat not in keywords:
            keywords.append(cat)
    
    # 3. Trích xuất từ URL
    url_category = extract_category_from_url(url)
    if url_category and url_category not in keywords:
        keywords.append(url_category)
    
    return keywords


def extract_content_from_html(html_content: str) -> str:
    """Trích xuất text từ HTML content trong RSS"""
    if not html_content:
        return ""
    
    try:
        soup = BeautifulSoup(html_content, "lxml")
        # Lấy tất cả text, loại bỏ tags
        text = soup.get_text(separator=" ", strip=True)
        # Làm sạch whitespace
        text = re.sub(r'\s+', ' ', text)
        return text.strip()
    except Exception:
        return html_content


def fetch_article_content(url: str) -> str:
    """
    Fetch nội dung đầy đủ từ URL bài viết
    Nếu RSS chỉ có summary, cần fetch trang gốc
    """
    try:
        html = fetch_text(url)
        soup = BeautifulSoup(html, "lxml")
        
        # Thử các selector phổ biến
        article_body = None
        selectors = [
            "article",
            ".article-content",
            ".post-content",
            ".entry-content",
            ".content",
            "main",
        ]
        
        for selector in selectors:
            article_body = soup.select_one(selector)
            if article_body:
                break
        
        if article_body:
            paragraphs = article_body.find_all("p")
            text_parts = []
            for p in paragraphs:
                text = p.get_text(strip=True)
                if text:
                    text_parts.append(text)
            return " ".join(text_parts)
        
        return ""
    except Exception as e:
        log(f"Failed to fetch article content from {url}: {e}")
        return ""


def parse_rss_entry(entry: Any, seen_urls: Set[str], fetch_full_content: bool = False) -> Optional[Dict[str, Any]]:
    """Parse một entry từ RSS feed"""
    
    # URL
    url = entry.get("link", "").strip()
    if not url or url in seen_urls:
        return None
    
    # Title
    title = entry.get("title", "").strip()
    
    # Published date
    pub = ""
    if hasattr(entry, "published_parsed") and entry.published_parsed:
        try:
            dt = datetime(*entry.published_parsed[:6], tzinfo=timezone.utc)
            pub = dt.isoformat()
        except Exception:
            pass
    
    if not pub and "published" in entry:
        pub = parse_rss_date(entry.published) or ""
    
    if not pub and "pubDate" in entry:
        pub = parse_rss_date(entry.pubDate) or ""
    
    # Content
    content_text = ""
    
    # Thử lấy content từ RSS
    if "content" in entry and entry.content:
        # feedparser trả về list
        content_html = entry.content[0].get("value", "") if isinstance(entry.content, list) else entry.content
        content_text = extract_content_from_html(content_html)
    
    # Nếu không có content, thử summary/description
    if not content_text:
        if "summary" in entry:
            content_text = extract_content_from_html(entry.summary)
        elif "description" in entry:
            content_text = extract_content_from_html(entry.description)
    
    # Nếu cần fetch full content từ URL gốc
    if fetch_full_content and url:
        full_content = fetch_article_content(url)
        if full_content and len(full_content) > len(content_text):
            content_text = full_content
    
    # Keywords - tự động trích xuất từ tags RSS hoặc URL
    keywords = extract_keywords_from_entry(entry, url)
    
    # Category - ưu tiên từ tags RSS, sau đó từ URL
    category = ""
    if keywords:
        category = keywords[0]  # Lấy keyword đầu tiên làm primary category
    
    # Author có thể là source
    author = entry.get("author", "")
    
    return {
        "url": url,
        "title": title,
        "published_at": pub,
        "content_text": content_text,
        "category": category,
        "keywords": keywords,
        "author": author,
    }


def make_row(data: Dict[str, Any]) -> Dict[str, Any]:
    return {
        "id": md5_id(data["url"]),
        "title": data.get("title") or "",
        "published_at": data.get("published_at") or "",
        "source.name": data.get("author") or SOURCE_NAME,
        "url": data["url"],
        "language": DEFAULT_LANGUAGE,
        "category.primary": data.get("category") or "",
        "keywords": "|".join(data.get("keywords") or []),
        "entities": "",
        "content.text": data.get("content_text") or "",
    }


def crawl_rss_feed(feed_url: str, end_date: str, seen_urls: Set[str], seen_ids: Set[str], fetch_full_content: bool = False) -> int:
    """
    Crawl RSS feed
    fetch_full_content: True nếu muốn fetch nội dung đầy đủ từ URL gốc
    """
    added = 0
    skipped_old = 0
    skipped_duplicate = 0
    
    try:
        # Parse RSS feed
        print(f"Fetching RSS feed: {feed_url}")
        feed = feedparser.parse(feed_url)
        
        if not feed.entries:
            print("No entries found in RSS feed")
            return 0
        
        print(f"Found {len(feed.entries)} entries in RSS feed")
        
        # Parse end_date
        end_dt = datetime.fromisoformat(end_date).replace(tzinfo=VN_TZ)
        
        for entry in feed.entries:
            try:
                # Parse entry
                data = parse_rss_entry(entry, seen_urls, fetch_full_content=False)
                if not data:
                    skipped_duplicate += 1
                    continue
                
                # Filter by date
                pub_iso = data.get("published_at")
                if pub_iso:
                    pub_local_date = iso_to_local_date(pub_iso)
                    if pub_local_date and pub_local_date < end_date:
                        skipped_old += 1
                        continue
                
                # Check duplicate by ID
                aid = md5_id(data["url"])
                if aid in seen_ids:
                    skipped_duplicate += 1
                    continue
                
                # Fetch full content if needed
                if fetch_full_content:
                    full_content = fetch_article_content(data["url"])
                    if full_content and len(full_content) > len(data.get("content_text", "")):
                        data["content_text"] = full_content
                
                # Ghi bài vào CSV
                row = make_row(data)
                append_row(CSV_PATH, row)
                seen_urls.add(data["url"])
                seen_ids.add(aid)
                added += 1
                
                print(f"Added: {data.get('title', '')[:80]}")
                
                if fetch_full_content:
                    polite_sleep()
                    
            except Exception as e:
                log(f"Error processing entry: {e}")
                continue
        
        # Summary log
        print(f"\nSummary: {added} added, {skipped_duplicate} duplicates, {skipped_old} old")
        return added
        
    except Exception as e:
        print(f"Error crawling RSS feed: {e}")
        import traceback
        traceback.print_exc()
        return 0


def main():
    ensure_csv_header(CSV_PATH)
    seen_urls, seen_ids = load_seen_from_csv(CSV_PATH)
    
    total_added = 0
    
    for i, feed_url in enumerate(RSS_FEEDS, 1):
        print(f"\n{'='*80}")
        print(f"Processing RSS Feed {i}/{len(RSS_FEEDS)}")
        print(f"{'='*80}")
        
        try:
            added = crawl_rss_feed(feed_url, END_DATE, seen_urls, seen_ids, fetch_full_content=FETCH_FULL_CONTENT)
            total_added += added
            print(f"✓ Added {added} articles from this feed")
        except Exception as e:
            print(f"✗ Error with feed {feed_url}: {e}")
            continue
        
        # Delay giữa các feeds
        if i < len(RSS_FEEDS):
            time.sleep(2)
    
    print(f"\n{'='*80}")
    print(f"SUMMARY")
    print(f"{'='*80}")
    print(f"Total feeds processed: {len(RSS_FEEDS)}")
    print(f"Total articles added: {total_added}")
    print(f"Output file: {CSV_PATH}")
    print(f"{'='*80}")


if __name__ == "__main__":
    main()
# Out:
# ================================================================================
# Processing RSS Feed 1/137
# ================================================================================
# Fetching RSS feed: https://vnexpress.net/rss/tin-moi-nhat.rss
# Found 54 entries in RSS feed
# Added: Tên cướp ngân hàng ném tiền vào xe rác khi tháo chạy
# Added: Sắp có nghị quyết gỡ vướng Nghị định 46 về an toàn thực phẩm
# Added: Ông Tập đề xuất 'kế hoạch lớn' với ông Putin để phát triển quan hệ
# Added: Tôi vay 1,7 tỷ đồng mua nhà vì đi thuê mười năm mất hơn một tỷ
# Added: Đường dây cung cấp ma túy liên tỉnh bị triệt phá
# Added: Kẻ cướp ngân hàng bị khống chế tại hiện trường
# Added: Những sai lầm khiến bệnh răng miệng dễ xuất hiện dịp Tết
# Added: 200 nhà khoa học chia sẻ về xu hướng công nghệ sinh học và năng lượng
# Added: Hai trùm buôn lậu 546 kg vàng bị tuyên 10 năm tù
# Added: Tập đoàn Nhật Bản rót 1.900 tỷ đồng mua dự án cao ốc ở TP HCM
# Added: Xe buýt đi sân bay Long Thành nên có làn riêng để đảm bảo đúng giờ'?
# Added: Trung tâm tài chính, khu thương mại tự do 'hút' chú ý của FDI
# Added: Ông Trump làm lành với Tổng thống Colombia sau căng thẳng
# Added: Pháp triệu tập Elon Musk, khám xét văn phòng của X
# Added: Chồng cũ của bà Jill Biden bị nghi giết vợ
# Added: Ông Trump: 'Ông Putin đã giữ lời hứa dừng tập kích Kiev'
# Added: Mỹ tuyên bố bắn rơi UAV Iran áp sát tàu sân bay
# Added: Phi công ngoại thất thế ở Trung Quốc
# Added: Thẩm phán Mỹ 'cứu' 350.000 người Haiti khỏi nguy cơ bị trục xuất
# Added: 'Sự cố liên lạc' suýt làm phá sản Chiến dịch Búa đêm của Mỹ
# Added: Ông Trump có thể 'vừa đá bóng vừa thổi còi' khi kiện Bộ Tài chính Mỹ
# Added: Đặc phái viên của Tổng Bí thư Tô Lâm hội đàm với Ngoại trưởng Trung Quốc
# Added: Xuồng vũ trang Iran tiếp cận tàu chở dầu Mỹ
#
# Summary: 26 added, 34 duplicates, 0 old
# ✓ Added 26 articles from this feed
#
# ================================================================================
# Processing RSS Feed 4/137
# ================================================================================
# Fetching RSS feed: https://vnexpress.net/rss/kinh-doanh.rss
# Found 60 entries in RSS feed
# Added: Lý do hàng nhập khẩu thực phẩm, nông sản ách tắc
# Added: VN-Index xuống thấp nhất một tháng
# Added: Chính phủ Mỹ sắp cấp phép khai thác dầu khí tại Venezuela
# Added: Thảo Cầm Viên lãi liên tiếp 5 năm
# Added: Thống đốc Fed rời chức vụ tại Nhà Trắng
# Added: Bitcoin rơi về mức thấp nhất kể từ khi ông Trump đắc cử
# Added: Mỗi lượng vàng miếng tăng thêm gần 4 triệu đồng
# Added: Hãng bán lẻ Walmart đạt vốn hóa 1.000 tỷ USD
# Added: Thủ tướng yêu cầu 'thông quan ngay' hàng ách tắc tại cửa khẩu
# Added: Giá vàng thế giới tăng mạnh nhất 17 năm
# Added: Tiền ở đâu để doanh nghiệp Việt mở rộng sản xuất xanh?
# Added: Cú trượt chân của 'báo nhảy' Puma
# Added: ACV thay người phụ trách ban điều hành
# Added: Hướng dẫn chi tiết cách kê khai, nộp thuế cho cá nhân, hộ kinh doanh
# Added: Chứng khoán mở rộng cửa hơn cho nhà đầu tư nước ngoài
# Added: Vingroup hợp tác phát triển hệ sinh thái tại bang Tamil Nadu
# Added: Jordan muốn lập khu thương mại tự do cho hàng Việt xuất sang Trung Đông
#
# Summary: 17 added, 43 duplicates, 0 old
# ✓ Added 17 articles from this feed
#
# ================================================================================
# Processing RSS Feed 5/137
# ================================================================================
# Fetching RSS feed: https://vnexpress.net/rss/giai-tri.rss
# Found 60 entries in RSS feed
# Added: Màn đu dây của Hòa Minzy ở concert gây tranh luận
# Added: Nghệ sĩ Việt Anh: 'Tôi biết ơn vì hạnh phúc tuổi xế chiều'
# Added: Park Shin Hye tỏa sáng với vai diễn hai mặt
# Added: 'Võ Tắc Thiên' Lưu Hiểu Khánh bán chữ
# Added: Tài tử 'Tiếng yêu này anh dịch được không?' xin lỗi
# Added: 'Điều kỳ diệu ở vương quốc Sách'
# Added: Bố vợ Brooklyn Beckham: Con rể tôi tuyệt vời
# Added: Phim về bà Melania Trump hút khán giả dù bị chê nội dung
# Added: Duyên Quỳnh xin lỗi sau khi lộ hát nhép
# Added: Mỹ Tâm, Mai Tài Phến sánh đôi
#
# Summary: 10 added, 50 duplicates, 0 old
# ✓ Added 10 articles from this feed
#
# ================================================================================
# Processing RSS Feed 6/137
# ================================================================================
# Fetching RSS feed: https://vnexpress.net/rss/the-thao.rss
# Found 60 entries in RSS feed
# Added: Chelsea hóa giải bài phạt góc của Arsenal thế nào
# Added: Man Utd khó lòng thay thế Casemiro
# Added: Kiplimo không được công nhận kỷ lục half marathon thế giới
# Added: Chuyên gia Arab Saudi: 'Ronaldo ảo tưởng vai trò ở Al Nassr'
# Added: Redknapp: 'Arsenal đủ sức giành cú ăn ba mùa này'
# Added: Arteta: 'Chung kết Cup Liên đoàn là liều vitamin tốt nhất cho Arsenal'
# Added: Guardiola chê các đối thủ chi tiêu mạnh ở Ngoại hạng Anh
# Added: Ngoại hạng Anh vẫn thống trị chuyển nhượng mùa Đông
# Added: Barca vào bán kết Cup Nhà vua
# Added: Arsenal loại Chelsea, vào chung kết Cup Liên đoàn
# Added: Việt Nam bị Indonesia loại ở futsal châu Á
#
# Summary: 11 added, 49 duplicates, 0 old
# ✓ Added 11 articles from this feed
#
# ================================================================================
# Processing RSS Feed 7/137
# ================================================================================
# Fetching RSS feed: https://vnexpress.net/rss/phap-luat.rss
# Found 60 entries in RSS feed
# Added: Trinh sát TP HCM lần theo dấu vết, bắt băng ma túy 36 người
# Added: VKS buộc hai 'trùm' buôn lậu 546 kg vàng nộp lại 1.200 tỷ đồng
# Added: Ba cựu Phó chủ tịch TP Long Xuyên lĩnh án vì sai phạm tái định cư
# Added: Giám đốc bị bắt vì làm giả hơn 200 tấn lúa giống ST25, ST24
# Added: Lời khai của chủ tiệm gội đầu 'cõng' 97 kg vàng lậu từ Trung Quốc vào Việt Nam
# Added: Cái chết bí ẩn của nữ bác sĩ trong kho đông lạnh ở siêu thị
# Added: Bên trong 'boongke' của kẻ bán ma túy qua khe cửa
# Added: Cảnh sát theo dõi, bắt đường dây lén bán gần 30.000 thuốc lá điện tử
# Added: Đường dây buôn lậu nửa tấn vàng giấu trong giày từ Trung Quốc bị xét xử
# Added: Hai cha con bị bắt sau vụ đánh người trên đảo Phú Quý
# Added: Kẻ sống kín tiếng bán ma túy qua khe cửa hẹp
# Added: Toà án: Xây tiếp tháp bỏ hoang của VICEM, hơn 100 năm mới thu hồi vốn
# Added: Âm mưu trả thù hèn hạ của tử tù trẻ tuổi nhất Hàn Quốc
#
# Summary: 13 added, 47 duplicates, 0 old
# ✓ Added 13 articles from this feed
#
# ================================================================================
# Processing RSS Feed 8/137
# ================================================================================
# Fetching RSS feed: https://vnexpress.net/rss/giao-duc.rss
# Found 60 entries in RSS feed
# Added: Bộ Giáo dục: Không có đề minh họa thi tốt nghiệp THPT 2026
# Added: Cấm giáo viên ép học sinh, phụ huynh tham gia hoạt động tự nguyện
# Added: Giới hạn 10 nguyện vọng đại học là 'đẩy phần khó' cho thí sinh
# Added: Bộ Quốc phòng lần đầu tổ chức thi đánh giá năng lực
# Added: Học sinh TP HCM có thể thi lớp 10 vào cuối tháng 5
#
# Summary: 5 added, 55 duplicates, 0 old
# ✓ Added 5 articles from this feed
#
# ================================================================================
# Processing RSS Feed 9/137
# ================================================================================
# Fetching RSS feed: https://vnexpress.net/rss/suc-khoe.rss
# Found 60 entries in RSS feed
# Added: Bệnh viện náo loạn vì quả đạn pháo Thế chiến I trong trực tràng bệnh nhân
# Added: Tưởng mệt do chơi thể thao, chàng trai suýt chết vì thuyên tắc phổi
# Added: Cụ bà nguy kịch do chó cắn
# Added: Estée Lauder bị phạt 750.000 CAD vì bán mỹ phẩm chứa 'hóa chất vĩnh cửu'
# Added: Thức khuya, nghiện màn hình - 'combo' tàn phá mắt
# Added: Chế biến thịt thế nào tốt cho sức khỏe
# Added: Chế độ ăn giúp giảm nguy cơ bệnh thận
# Added: Thiếu niên 17 tuổi trở về từ cửa tử nhờ trái tim người lạ
# Added: 46 người ở TP HCM nghi ngộ độc sau ăn tiệc tất niên
# Added: Có nên ngủ ngay sau khi uống rượu?
# Added: 5 bệnh 'sát thủ thầm lặng' ít dấu hiệu cảnh báo
# Added: Vì sao trẻ cần 'ốm vặt' nhiều lần trước 6 tuổi?
# Added: Lợi ích sức khỏe của giấm táo
# Added: Lợi ích của nước dừa với hệ tiêu hóa
# Added: 7 gia vị giúp cơ thể giữ ấm khi trời lạnh
# Added: Có con sau 5 lần sàng lọc phôi thụ tinh ống nghiệm
# Added: Són tiểu gây nhiễm khuẩn đường tiết niệu
# Added: Tại sao ăn bơ giúp giảm cân?
# Added: U xuất huyết khiến máu tràn vào phổi
# Added: Bắt 16 vít nắn thẳng cột sống vẹo lệch của bé gái
# Added: Những bệnh truyền nhiễm dễ mắc dịp Tết
# Added: 6 vitamin, khoáng chất giúp cân bằng nội tiết tố nữ
# Added: Ngưng thở khi ngủ nặng gây tăng huyết áp
# Added: Tiêm huyết tương chữa rụng tóc
# Added: Bé 9 tuổi xuất huyết tiêu hóa sau hai tháng đau bụng
# Added: Các biện pháp thay đổi lối sống giảm nguy cơ ung thư
# Added: Massage đầu có giúp dễ ngủ không?
# Added: Ba người trong gia đình cùng cận thị, đục thủy tinh thể
# Added: Dấu hiệu cảnh báo thoái hóa điểm vàng
# Added: Tưởng đau dạ dày hóa túi mật hoại tử
# Added: Xạ trị giúp người phụ nữ ung thư giữ lại đôi mắt
#
# Summary: 31 added, 29 duplicates, 0 old
# ✓ Added 31 articles from this feed
#
# ================================================================================
# Processing RSS Feed 10/137
# ================================================================================
# Fetching RSS feed: https://vnexpress.net/rss/gia-dinh.rss
# Found 60 entries in RSS feed
# Added: Sai lầm khi dọn dẹp 'mời' chuột và côn trùng vào nhà
# Added: Giấu bớt kinh nghiệm để xin việc
# Added: Ăn trái cây trong mùa lạnh thế nào cho đúng?
# Added: Cú 'sốc' ngọt ngào của cô gái Việt làm dâu Mông Cổ
# Added: Bé gái bị nấm 'ăn não' khi dọn nhà đón Tết
#
# Summary: 5 added, 55 duplicates, 0 old
# ✓ Added 5 articles from this feed
#
# ================================================================================
# Processing RSS Feed 11/137
# ================================================================================
# Fetching RSS feed: https://vnexpress.net/rss/du-lich.rss
# Found 60 entries in RSS feed
# Added: Loạt điểm đến nổi tiếng Việt Nam trong phim 'Người bất tử'
# Added: Du khách bị voi giẫm chết ở Thái Lan
# Added: Khách nước ngoài bày mâm ngũ quả, lên chùa cúng Tết Việt
# Added: Nhà thám hiểm Mỹ kể bạn đồng hành bị bộ lạc Amazon tấn công
# Added: Vé máy bay giá rẻ có thể 'phá hỏng' kỳ nghỉ
# Added: Quán xôi vỉa hè hơn 40 năm giữ chân khách ở phố cổ Hà Nội
#
# Summary: 6 added, 54 duplicates, 0 old
# ✓ Added 6 articles from this feed
#
# ================================================================================
# Processing RSS Feed 12/137
# ================================================================================
# Fetching RSS feed: https://vnexpress.net/rss/khoa-hoc.rss
# Found 60 entries in RSS feed
# Added: Robot hình người Trung Quốc chạy nhanh nhất thế giới
# Added: Cấu hình iPhone gập dần lộ diện
# Added: Intel sắp sản xuất GPU cho trung tâm dữ liệu
# Added: Nvidia thay Apple thành khách hàng lớn nhất của TSMC
# Added: CEO Telegram chỉ trích Pháp sau vụ khám xét X
# Added: Công ty đào hầm xuyên lòng đất của Elon Musk hiện thế nào
#
# Summary: 6 added, 54 duplicates, 0 old
# ✓ Added 6 articles from this feed
#
# ================================================================================
# Processing RSS Feed 13/137
# ================================================================================
# Fetching RSS feed: https://vnexpress.net/rss/so-hoa.rss
# Found 60 entries in RSS feed
#
# Summary: 0 added, 60 duplicates, 0 old
# ✓ Added 0 articles from this feed
#
# ================================================================================
# Processing RSS Feed 14/137
# ================================================================================
# Fetching RSS feed: https://vnexpress.net/rss/oto-xe-may.rss
# Found 60 entries in RSS feed
# Added: Quy định mới 'chặn đường sống' của tay nắm cửa ẩn
# Added: Những bộ phận trên ôtô bắt buộc phải sạch
# Added: SUV mới của Toyota có thể thay thế Highlander
# Added: Doanh số Tesla tụt đáy ở 'vương quốc xe điện'
# Added: Bé gái lao sang đường từ góc khuất suýt bị xe buýt đâm trúng
# Added: Hai hãng Trung Quốc mang cuộc chiến giá xe ra nước ngoài
# Added: Những kiểu cần gạt mưa không nhiều người để ý
# Added: Gắn nhiều đồ chơi trên xe có bị phạt?
#
# Summary: 8 added, 52 duplicates, 0 old
# ✓ Added 8 articles from this feed
#
# ================================================================================
# Processing RSS Feed 15/137
# ================================================================================
# Fetching RSS feed: https://vnexpress.net/rss/y-kien.rss
# Found 60 entries in RSS feed
# Added: Chồng tôi muốn nghỉ việc lương 15 triệu để khởi nghiệp ở tuổi 45
# Added: Tiệm vàng 'hết tiền' khi tôi cần bán gấp 20 lượng vàng nhẫn 9999
# Added: Kinh doanh hoa Tết lỗ đậm vì khách trả cặp vạn thọ 120 nghìn đồng vẫn không bán
# Added: Vì sao 4 năm không giải quyết dứt điểm vụ hai cây xăng trên cao tốc ngừng bán?
# Added: Nhà sản xuất mua lại bao bì để ngăn vứt bừa bãi ở ruộng vườn
# Added: 'Nên xử phạt người hút thuốc lá khi lái xe bằng camera AI'
# Added: Trẻ ăn cá viên chiên trong lễ hội xuân ở trường mầm non
#
# Summary: 7 added, 53 duplicates, 0 old
# ✓ Added 7 articles from this feed
#
# ================================================================================
# Processing RSS Feed 16/137
# ================================================================================
# Fetching RSS feed: https://dantri.com.vn/rss/trang-chu.rss
# No entries found in RSS feed
# ✓ Added 0 articles from this feed
#
# ================================================================================
# Processing RSS Feed 17/137
# ================================================================================
# Fetching RSS feed: https://dantri.com.vn/rss/xa-hoi.rss
# Found 100 entries in RSS feed
#
# Summary: 0 added, 0 duplicates, 100 old
# ✓ Added 0 articles from this feed
#
# ================================================================================
# Processing RSS Feed 18/137
# ================================================================================
# Fetching RSS feed: https://dantri.com.vn/rss/the-gioi.rss
# Found 100 entries in RSS feed
# Added: Ukraine điều chỉnh lập trường đàm phán sau cuộc tập kích lớn của Nga
# Added: Bên trong kho tên lửa lớn nhất Trung Đông của Iran
# Added: Elon Musk trở thành người đầu tiên trên thế giới có 800 tỷ USD
# Added: Bắt đầu vòng 2 cuộc đàm phán hòa bình ba bên Nga - Ukraine - Mỹ
# Added: Đức Giáo hoàng kêu gọi Nga và Mỹ gia hạn hiệp ước vũ khí hạt nhân cuối cùng
# Added: Ukraine báo động Nga bắt đầu khai hỏa bằng "tàu sân bay trên không" giá rẻ
# Added: Dư chấn từ các tình tiết mới trong Hồ sơ Epstein
# Added: "Cơn sốt Sanae": Sức hút của Thủ tướng Nhật Bản với giới trẻ
# Added: Mỹ và Iran đổi địa điểm đàm phán hạt nhân
# Added: "Sát thủ" của Nga phía sau chiến tuyến khiến Ukraine toát mồ hôi
# Added: Nữ giáo viên 90 tuổi lập kỷ lục thế giới với sự nghiệp giảng dạy 67 năm
# Added: Mỹ thử nghiệm tên lửa hành trình mới cho Ukraine
# Added: Ukraine lộ điểm yếu, Nga chớp thời xâm nhập chốt chặn chiến lược
# Added: Chiến sự Ukraine 4/2: Ukraine đang "giăng bẫy" Nga ở Zaporizhia
# Added: Hàng nghìn người Venezuela tuần hành kêu gọi Mỹ thả Tổng thống Maduro
# Added: Kiev nguy cấp năng lượng sau trận tập kích tên lửa kỷ lục của Nga
# Added: Israel đưa ra 4 yêu cầu với Iran
# Added: Tính năng phục kích săn lùng mục tiêu của "sát thủ đại dương" Ukraine
# Added: Hé lộ về đơn vị đặc nhiệm JTF 2 của Canada: "Im lặng nhưng chết người"
# Added: Trung Quốc cảnh báo khi công ty Hong Kong bị hủy hợp đồng kênh đào Panama
# Added: Châu Âu - Mỹ sẽ bắt tay về đất hiếm, kiềm chế sự thống trị của Trung Quốc
# Added: Tổng thống Trump lên tiếng vụ Nga tập kích rung chuyển Ukraine
# Added: Ukraine hành động khẩn sau trận tập kích chưa từng có của tên lửa Nga
# Added: Nga cảnh báo khả năng "thế giới sẽ nguy hiểm hơn" trong vài ngày tới
# Added: Tín hiệu của Iran khi dàn khí tài Mỹ áp sát lãnh thổ
# Added: Con trai cựu lãnh đạo Libya Gaddafi bị ám sát
# Added: Mỹ thông qua gói chi tiêu lớn, chấm dứt đóng cửa chính phủ
# Added: Mỹ bắn rơi UAV Iran tiếp cận tàu sân bay
# Added: NATO: Phương Tây sẽ đưa binh sĩ tới Ukraine ngay sau thỏa thuận hòa bình
# Added: Tổng thống Trump đòi Đại học Harvard bồi thường 1 tỷ USD
# Added: Pháp triệu tập tỷ phú Elon Musk, khám xét văn phòng mạng xã hội X
# Added: Nga phóng hơn 500 tên lửa, UAV trong đêm, Ukraine cắt điện khẩn cấp
#
# Summary: 32 added, 68 duplicates, 0 old
# ✓ Added 32 articles from this feed
#
# ================================================================================
# Processing RSS Feed 19/137
# ================================================================================
# Fetching RSS feed: https://dantri.com.vn/rss/kinh-doanh.rss
# Found 100 entries in RSS feed
# Added: Cổ phiếu doanh nghiệp tỷ phú Trần Đình Long gây bất ngờ
# Added: Một thế lực mới trên thị trường vàng lộ diện, là “tay chơi” tiền số?
# Added: Canh bạc nghìn tỷ USD của Elon Musk với SpaceX và xAI
# Added: Biến động nhân sự cấp cao tại chủ đầu tư sân bay Long Thành
# Added: Vàng lấy lại mốc 5.000 USD/ounce
# Added: Lộ diện chủ đầu tư siêu dự án điện gió ngoài khơi hơn 48.000 tỷ đồng
# Added: Cao điểm nộp thuế, lãi suất liên ngân hàng lập đỉnh kỷ lục 17%/năm
# Added: Hải quan hỏa tốc yêu cầu toàn ngành trực 24/7 "giải cứu" hàng ùn ứ
# Added: Giá vàng vẽ mô hình chữ V hiếm gặp, chuyên gia vẫn cược mốc 6.300 USD
# Added: Công ty Đồ hộp Hạ Long báo lỗ nặng sau lùm xùm 130 tấn lợn bệnh
# Added: Công ty muốn mua dự án của ông Dũng "Lò Vôi" làm ăn ra sao?
# Added: Chuyên gia WGC: Đầu tư vàng năm 2026 đừng chỉ nhìn vào biến động giá
# Added: Giá xăng dầu ngày mai tăng hay giảm?
# Added: Giá vàng miếng vượt 180 triệu đồng/lượng
# Added: Ông Trần Hùng Huy tham gia Hội đồng Cố vấn của Đại học Quốc gia TPHCM
# Added: Bước chuyển của Petrolimex trong kỷ nguyên mới
# Added: Vingroup ký hợp tác để củng cố hệ sinh thái đa ngành tại Ấn Độ
# Added: Dự án điện gió Savan 1: Điểm nhấn hợp tác năng lượng Việt Nam và Lào
# Added: Tiếp viên Vietnam Airlines: Những “đại sứ” trên hành trình đa văn hóa
# Added: Sau ngày tồi tệ nhất từ năm 1980, Phố Wall vẫn cược vàng lên 6.300 USD
# Added: Shopee bắt tay nhà bán hàng nâng chuẩn thương mại điện tử trên sàn
# Added: Petrolimex giới thiệu nhận diện thương hiệu mới
#
# Summary: 22 added, 78 duplicates, 0 old
# ✓ Added 22 articles from this feed
#
# ================================================================================
# Processing RSS Feed 20/137
# ================================================================================
# Fetching RSS feed: https://dantri.com.vn/rss/the-thao.rss
# Found 100 entries in RSS feed
# Added: Hình ảnh gây chú ý của hai HLV Park Hang Seo và Kim Sang Sik
# Added: Báo Indonesia dự đoán về án phạt của Malaysia trước tuyển Việt Nam
# Added: Thất bại trước Indonesia và trình độ futsal Việt Nam ở bóng đá châu Á
# Added: Trưởng đoàn bóng đá Indonesia nhận án phạt nặng từ FIFA
# Added: Báo Đông Nam Á: “Futsal Indonesia đánh bại tuyển Việt Nam, tạo nên lịch sử”
# Added: Giới chủ Saudi Arabia ra tối hậu thư cứng rắn với C.Ronaldo
# Added: HLV Indonesia tuyên bố bất ngờ khi đội nhà thắng futsal Việt Nam
# Added: Báo Indonesia bình luận khi đội nhà thắng nghẹt thở tuyển futsal Việt Nam
# Added: Hành động bất ngờ của Alcaraz sau khi vô địch Australian Open
# Added: Arsenal loại Chelsea nghẹt thở, vào chung kết Cúp Liên đoàn Anh
# Added: Phản ứng của CĐV Đông Nam Á khi tuyển futsal Việt Nam thua Indonesia
# Added: Xác định hai cặp đấu bán kết giải futsal châu Á 2026
# Added: HLV futsal Việt Nam thẳng thắn nói về đội nhà sau trận thua Indonesia
# Added: Tuyển futsal Việt Nam thua Indonesia, dừng bước ở tứ kết giải châu Á
#
# Summary: 14 added, 86 duplicates, 0 old
# ✓ Added 14 articles from this feed
#
# ================================================================================
# Processing RSS Feed 21/137
# ================================================================================
# Fetching RSS feed: https://dantri.com.vn/rss/giai-tri.rss
# Found 100 entries in RSS feed
# Added: Màn đu dây "liều mạng" của Hòa Minzy gây tranh luận
# Added: Một năm ngày mất của Từ Hy Viên: Hai con vắng mặt, chồng viết thư cảm động
# Added: Khai mạc đợt phim chào mừng thành công Đại hội Đảng
# Added: Bố vợ tỷ phú khen con trai David Beckham là “người tuyệt vời”
# Added: NSND Quốc Khánh trở lại đóng Ngọc Hoàng, đồng nghiệp hé lộ sức khỏe
# Added: Anh Tú Atus đóng cặp sao nữ 18 tuổi, thừa nhận trả nợ ân tình Trường Giang
# Added: Công ty quản lý thừa nhận sai phạm trốn thuế của tài tử Kim Seon Ho
# Added: Xuân Hinh: "Tôi và Thanh Thanh Hiền giữ chừng mực, không có chuyện nọ kia"
# Added: Diễn viên Thúy Ngân: Sắc vóc tuổi 35 gây sốt, kín tiếng sau đổ vỡ tình cảm
# Added: "Người tình màn ảnh" của Steven Nguyễn: Tôi thích đàn ông ấm áp, tinh tế
# Added: Đêm nghệ thuật "Đường lên phía trước" - bản hòa ca về niềm tin và khát vọng
# Added: Bộ ảnh nội y táo bạo khiến “biểu tượng gợi cảm Hollywood” hứng chỉ trích
# Added: Ca sĩ Duyên Quỳnh xin lỗi, thừa nhận hát nhép bản hit 6,5 tỷ lượt xem
# Added: Danh ca 58 tuổi sắp lên chức cha lần thứ 8 cùng vợ á hậu kém tuổi
# Added: Phim Tài "né" chiếu mùng 1 Tết, Mỹ Tâm kể chuyện cãi nhau với Mai Tài Phến
#
# Summary: 15 added, 85 duplicates, 0 old
# ✓ Added 15 articles from this feed
#
# ================================================================================
# Processing RSS Feed 22/137
# ================================================================================
# Fetching RSS feed: https://dantri.com.vn/rss/giao-duc.rss
# Found 100 entries in RSS feed
# Added: Đà Nẵng chúc Tết du học sinh Lào là con cán bộ quân nhân
# Added: Họp phụ huynh kiểu lạ của cô giáo Gen Z gây “bão” mạng
# Added: Sẽ không có đề thi minh họa tốt nghiệp THPT năm 2026
# Added: Bộ Giáo dục cấm giáo viên sửa điểm thi của học sinh
# Added: Học sinh TPHCM có thể thi lớp 10 sớm hơn, vào cuối tháng 5
# Added: Chủ tịch tỉnh chỉ đạo xử lý dứt điểm lùm xùm vụ sửa điểm thi, lạm thu
# Added: Một trường đại học chi hơn 68 tỷ đồng thưởng Tết
# Added: Thiếu niên 15 tuổi "bỏ học", ở Singapore một mình làm nhiệm vụ bố giao
# Added: Nam sinh lớp 8 bị đuối nước ở hồ tưới
#
# Summary: 9 added, 91 duplicates, 0 old
# ✓ Added 9 articles from this feed
#
# ================================================================================
# Processing RSS Feed 23/137
# ================================================================================
# Fetching RSS feed: https://dantri.com.vn/rss/suc-khoe.rss
# Found 100 entries in RSS feed
# Added: Chụp X-quang đủ 6 phút mới thanh toán: BHXH nói gì?
# Added: Bệnh nhân chấn thương nghiêm trọng vì bị chó cắn
# Added: 46 người nhập viện cấp cứu, nghi ngộ độc sau bữa tiệc tất niên ở TPHCM
# Added: GS.TS Phạm Mạnh Hùng giữ chức Viện trưởng Viện Tim mạch, Bệnh viện 19-8
# Added: Những dấu hiệu giúp nhận diện sớm nhân tuyến giáp tiềm ẩn nguy cơ
# Added: Hàng dài y bác sĩ ở TPHCM tiễn đưa vị Phó giáo sư đáng kính ngày cận Tết
# Added: Loại củ "tốt nhất thế giới" trồng bạt ngàn tại Việt Nam
# Added: Tin mừng cho người muốn tỉnh táo mà không cần cà phê
# Added: Công bố kết quả kiểm tra 121 trung tâm hội nghị, nhà hàng tiệc cưới ở TPHCM
# Added: Long Châu và Bayer phối hợp Bộ Y tế triển khai chương trình phòng chống đột quỵ
# Added: Già hóa nhanh: Từ thách thức đến giải pháp chăm sóc sức khỏe người cao tuổi
#
# Summary: 11 added, 89 duplicates, 0 old
# ✓ Added 11 articles from this feed
#
# ================================================================================
# Processing RSS Feed 24/137
# ================================================================================
# Fetching RSS feed: https://dantri.com.vn/rss/du-lich.rss
# Found 100 entries in RSS feed
# Added: Mỹ: Bé gái 12 tuổi rơi từ cáp treo, gần chục người bên dưới lao tới đỡ
# Added: Miễn phí vé tham quan nhiều điểm du lịch nổi tiếng ở Thanh Hóa
# Added: Hai bộ xương cá voi 300 năm tuổi ở Lý Sơn bị hư hỏng
# Added: Linh vật ngựa béo gây sốt ở Trung Quốc, được ví như... Bát Giới
# Added: Đức có bến tàu mang tên Đồng Xuân
# Added: Khách Việt chi gần 150 triệu đồng du lịch châu Âu trong dịp Tết Nguyên đán
# Added: Tưởng bánh rán, khách Tây sửng sốt khi thấy nguyên liệu bò lúc nhúc
# Added: Cầu Rồng phun lửa nhiều đêm, cầu sông Hàn cũng quay nhịp trong Tết
# Added: Sắp khai màn lễ hội Tết ven biển Cần Giờ với loạt trải nghiệm thú vị
#
# Summary: 9 added, 91 duplicates, 0 old
# ✓ Added 9 articles from this feed
#
# ================================================================================
# Processing RSS Feed 25/137
# Added: Tín dụng bứt tốc, cổ phiếu ngân hàng vẫn phân hóa mạnh: Điều gì quyết định cuộc
# Added: Vé máy bay Tết nhiều chặng khan hiếm, giá tăng vọt
# Added: Thủ tướng: Không để ách tắc hàng thực phẩm, thiết lập đường dây nóng 24/7
# Added: Thép Pomina năm thứ 4 liên tiếp thua lỗ
# Added: Nhờ AI tư vấn đón Tết, kinh nghiệm 'thời ông bà' đang bị thách thức?
# Added: Giá vàng thế giới tăng mạnh, vượt 4.900 USD/ounce
#
# Summary: 24 added, 26 duplicates, 0 old
# ✓ Added 24 articles from this feed
#
# ================================================================================
# Processing RSS Feed 31/137
# ================================================================================
# Fetching RSS feed: https://tuoitre.vn/rss/giao-duc.rss
# Found 50 entries in RSS feed
# Added: Sinh viên Trường đại học Lạc Hồng vượt 5.000 dự án, giành giải bạc GovTech toàn
# Added: Bộ Quốc phòng công bố cấu trúc chi tiết đề thi đánh giá năng lực
# Added: Hội xuân trường học toàn snack, nước ngọt: Niềm vui tuổi thơ hay dễ dãi với đồ ă
# Added: TP.HCM ra thông báo khẩn về tuyển sinh đầu cấp
# Added: Học sinh Hàn Quốc thích thú tìm hiểu, trải nghiệm văn hóa Đà Nẵng
# Added: Hội xuân trong trường thu 270.000 đồng: Trải nghiệm giáo dục hay phân biệt học t
# Added: Đại học Kinh tế TP.HCM: QS và THE trong bức tranh quản trị đại học
# Added: Vì sao Việt Nam lọt nhóm 5 thị trường giáo dục ưu tiên của Anh?
# Added: Nhiều điểm mới trong quy tắc ứng xử của nhà giáo
# Added: Cảnh báo lừa đảo tuyển giáo viên tại Tuyên Quang
# Added: Bị tố lạm thu, Trường THCS Lê Hồng Phong (Khánh Hòa) nói 'phụ huynh tự nguyện'
# Added: Đào tạo 4.000 nhân lực cho các nhà máy điện hạt nhân đến 2035
# Added: 'Săn' tài liệu miễn phí, đoạt giải nhất môn hóa quốc gia
# Added: Tuyển sinh lớp 10 ở TP.HCM: Có thể thi vào cuối tháng 5-2026
# Added: Choáng với tờ bài tập về nhà ‘to bằng cái mền’ của học sinh Trung Quốc
#
# Summary: 15 added, 35 duplicates, 0 old
# ✓ Added 15 articles from this feed
#
# ================================================================================
# Processing RSS Feed 32/137
# ================================================================================
# Fetching RSS feed: https://tuoitre.vn/rss/the-thao.rss
# Found 50 entries in RSS feed
# Added: Xác định đồng đội mới của Trần Quyết Chiến tại Giải đồng đội thế giới
# Added: Văn Khang, Công Phương nhận bằng khen của Bộ trưởng Bộ Quốc phòng
# Added: Malaysia nhận thêm tin dữ từ CAS, cận kề án xử thua tuyển Việt Nam
# Added: 'Nàng A Châu' bị tổn hại hình ảnh vì cựu trụ trì Thiếu Lâm Tự
# Added: Đội tuyển U23 Việt Nam được tặng xe máy
# Added: Sau FIFA, IOC cũng muốn đưa Nga trở lại Olympic
# Added: Bất mãn với bóng đá Ả Rập, Ronaldo muốn quay về châu Âu
# Added: Bóng chuyền nữ Việt Nam: Liệu có cơ hội dự VNL?
# Added: Gấu Nga sắp hết 'ngủ đông'
# Added: HLV Pep Guardiola: 'Các đội bóng chi tiêu nhiều thì phải biết vô địch'
# Added: HLV Indonesia vẫn không vui dù thắng tuyển futsal Việt Nam
# Added: Trẻ em có nên học pickleball, thay vì tennis, bóng bàn, cầu lông?
# Added: Đánh bại Chelsea, Arsenal vào chung kết Cúp Liên đoàn
# Added: Thua Indonesia, HLV tuyển futsal Việt Nam: Chúng tôi xứng đáng hòa hoặc thắng
# Added: CĐV bóng đá Thái Lan suy sụp vì 'sân cỏ thua Việt Nam, futsal thua Indonesia'
#
# Summary: 15 added, 35 duplicates, 0 old
# ✓ Added 15 articles from this feed
#
# ================================================================================
# Processing RSS Feed 33/137
# ================================================================================
# Fetching RSS feed: https://tuoitre.vn/rss/giai-tri.rss
# Found 50 entries in RSS feed
# Added: Top 5 anime fantasy dành cho fan cứng của Studio Ghibli
# Added: 5 ngày cuối đời của Từ Hy Viên: Bệnh tình chuyển nặng, không thể về nhà
# Added: Đồi gió hú là bộ phim 'bắt trọn nỗi khao khát và bản chất của ham muốn'
# Added: Monarch: Legacy of Monsters mùa 2 hé lộ Titan mới nguy hiểm hơn cả Godzilla
# Added: Brooklyn Beckham 'bóc phốt' cha mẹ để bảo vệ em gái Harper?
# Added: Mina Sue Choi là ai mà khiến show hẹn hò Single’s Inferno 5 chia rẽ?
# Added: Steven Nguyễn và Minh Trang sẽ có chuyện tình gây thương nhớ trong Không giới hạ
# Added: Giải thưởng âm nhạc: Mới chỉ vinh danh những gì hot nhất?
# Added: Vì sao khán giả Việt phát cuồng vì 'Tiểu yêu quái núi Lãng Lãng'?
# Added: Kim Seon Ho xin lỗi vì trốn thuế
# Added: Quán Kỳ Nam thua lỗ, rời rạp với 5,15 tỉ đồng
# Added: Gu thời trang độc lạ của ngôi sao có doanh thu phòng vé cao nhất lịch sử
# Added: Ba giọng ca của K-pop Demon Hunters sẽ biểu diễn tại BAFTA
# Added: Duyên Quỳnh xin lỗi, nói rút kinh nghiệm sau ồn ào hát nhép
# Added: Year End Party nhà DatVietVAC - quy tụ và gắn kết giá trị
#
# Summary: 15 added, 35 duplicates, 0 old
# ✓ Added 15 articles from this feed
#
# ================================================================================
# Processing RSS Feed 34/137
# ================================================================================
# Fetching RSS feed: https://tuoitre.vn/rss/xe.rss
# Found 50 entries in RSS feed
# Added: Trung Quốc ban hành quy định mới về truyền dữ liệu ô tô xuyên biên giới
# Added: Xe điện chạy gần 600km/ngày, pin vẫn gần như mới xuất xưởng
# Added: Xe máy lột xác khó tin: Do não bộ điều khiển, tự 'nhả' pin để giảm trọng lượng
# Added: Honda Super Cub C125 2026 thêm bản không yên sau, màu mới 'ngầu' hơn, giá tăng s
# Added: Xe điện chở theo cả máy bay: Nhỉnh hơn VW Viloran, chạy tới 1.000km
# Added: Yamaha ra mắt xe máy điện mới: 169km/sạc, giá ngang Honda Air Blade
#
# Summary: 6 added, 44 duplicates, 0 old
# ✓ Added 6 articles from this feed
#
# ================================================================================
# Processing RSS Feed 35/137
# ================================================================================
# Fetching RSS feed: https://thanhnien.vn/rss/home.rss
# Found 60 entries in RSS feed
# ...
# Added: Hội chợ Mùa Xuân 2026: Thủ tướng yêu cầu tăng cường quảng bá sản phẩm, thương hi
# Added: Đồng Tháp trồng hơn 2,25 triệu chậu hoa cảnh phục vụ Tết
#
# Summary: 9 added, 1 duplicates, 0 old
# ✓ Added 9 articles from this feed
#
# ================================================================================
# Processing RSS Feed 124/137
# ================================================================================
# Fetching RSS feed: https://baotintuc.vn/xa-hoi.rss
# Found 10 entries in RSS feed
# Added: Chúc Tết, tặng quà cho gia đình chính sách, hộ nghèo nhân dịp Tết Nguyên đán
# Added: Thưởng Tết Bính Ngọ 2026 tăng hơn năm ngoái dù kinh tế nhiều biến động
# Added: Xuân tình nguyện san sẻ yêu thương
# Added: TP Hồ Chí Minh trao 300 phần quà Tết cho hộ khó khăn
# Added: TP Hồ Chí Minh miễn phí vé đi xe buýt thứ 6 hàng tuần khi thanh toán số
# Added: Dấu ấn nhân văn từ chương trình 'Mẹ đỡ đầu'
# Added: Tết Công đoàn 2026 lan tỏa nghĩa tình chăm lo đoàn viên, người lao động
# Added: Bỏ phố về làng: Khi người trẻ mở lối, nghề truyền thống hồi sinh
# Added: Chăm lo Tết cho người dân bị thiệt hại do thiên tai, trẻ em có hoàn cảnh đặc biệ
# Added: TP Hồ Chí Minh kiểm soát an toàn thực phẩm mùa Tết - Bài cuối: Doanh nghiệp gắn
#
# Summary: 10 added, 0 duplicates, 0 old
# ✓ Added 10 articles from this feed
#
# ================================================================================
# Processing RSS Feed 125/137
# ================================================================================
# Fetching RSS feed: https://baotintuc.vn/phap-luat.rss
# Found 10 entries in RSS feed
# Added: Lào Cai bắt giữ đối tượng cướp ngân hàng
# Added: Phạt tù 11 bị cáo trong đường dây buôn lậu vàng từ Trung Quốc về Việt Nam
# Added: Hà Nội triển khai thí điểm khởi kiện tố tụng công ích
# Added: Tai nạn giao thông khiến một cán bộ Cảnh sát giao thông hy sinh
# Added: Phạt tù hai đối tượng dùng xuồng chở người nhập cảnh trái phép
# Added: Triệt phá nhóm cho vay lãi nặng lên đến trên 1.000%
# Added: Xử lý nhóm đối tượng trộm cắp tài sản, sản xuất và buôn bán hàng giả
# Added: Công an TP Hồ Chí Minh triệt phá đường dây ma túy liên tỉnh, bắt giữ 36 đối tượn
# Added: Đảm an toàn giao thông dịp Tết và Lễ hội Xuân 2026
# Added: Phối hợp bắt giữ 2 phương tiện khai thác cát trái phép trên sông Lam
#
# Summary: 10 added, 0 duplicates, 0 old
# ✓ Added 10 articles from this feed
#
# ================================================================================
# Processing RSS Feed 126/137
# ================================================================================
# Fetching RSS feed: https://baotintuc.vn/giao-duc.rss
# Found 10 entries in RSS feed
# Added: Không công bố đề thi minh họa Kỳ thi tốt nghiệp THPT năm 2026
# Added: Sở GD-ĐT TP Hồ Chí Minh cảnh báo lừa đảo mạo danh tuyển sinh đầu cấp
# Added: Tạo không gian đối thoại học thuật Việt Nam - Hàn Quốc về hóa học xanh
# Added: Lo ngại nảy sinh khi chính phủ Anh cân nhắc cấm điện thoại thông minh tại trường
# Added: Báo chí Hàn Quốc đưa tin về cơn sốt tiếng Hàn tại Việt Nam
# Added: Bộ Giáo dục và Đào tạo ban hành Quy tắc ứng xử của nhà giáo
#
# Summary: 6 added, 4 duplicates, 0 old
# ✓ Added 6 articles from this feed
#
# ================================================================================
# Processing RSS Feed 127/137
# ================================================================================
# Fetching RSS feed: https://baotintuc.vn/van-hoa.rss
# Found 10 entries in RSS feed
# Added: Tu bổ, phục hồi Quần thể di tích Tây Sơn Thượng Đạo (Gia Lai)
# Added: Công nhận 30 bảo vật quốc gia
# Added: Sắc xuân ba miền sống động qua ngôn ngữ xiếc
# Added: Nhân vật phản diện trong Harry Potter bất ngờ xuất hiện khắp Trung Quốc trước Tế
# Added: Rộn ràng sắc xuân nghệ thuật tại Hội chợ Mùa Xuân 2026
# Added: Đến Đà Nẵng thưởng thức cầu Rồng phun nước, phun lửa và quay nhịp cầu Sông Hàn
# Added: BTS lập dấu mốc mới cho văn hóa Hàn Quốc với concert live toàn cầu
# Added: Sân khấu TP Hồ Chí Minh sáng đèn mùa Tết Bính Ngọ 2026
# Added: Vĩnh Long khai mạc Hội sách, báo Xuân 2026
#
# Summary: 9 added, 1 duplicates, 0 old
# ✓ Added 9 articles from this feed
#
# ================================================================================
# Processing RSS Feed 128/137
# ================================================================================
# Fetching RSS feed: https://baotintuc.vn/the-thao.rss
# Found 10 entries in RSS feed
# Added: Trao thưởng đội tuyển U23 Việt Nam
# Added: Những tín hiệu lạc quan về sự chuyển giao thế hệ của Futsal Việt Nam
#
# Summary: 2 added, 8 duplicates, 0 old
# ✓ Added 2 articles from this feed
#
# ================================================================================
# Processing RSS Feed 129/137
# ================================================================================
# Fetching RSS feed: https://baotintuc.vn/quan-su.rss
# Found 10 entries in RSS feed
# Added: Nga bị cáo buộc do thám các vệ tinh quan trọng của châu Âu
# Added: Đức bắt giữ hai công dân nước ngoài tình nghi dùng sỏi phá hoại tàu chiến
# Added: Truyền thông Iran lên tiếng sau khi Mỹ thông báo bắn hạ UAV Shahed-129 trên biển
# Added: NATO bắt đầu lên kế hoạch cho chiến dịch 'Canh gác Bắc Cực' tại Greenland
# Added: Hiệp ước hạt nhân Mỹ - Nga bên bờ sụp đổ và những hệ lụy toàn cầu
# Added: Tiêm kích F-35 Mỹ bắn hạ UAV Iran ‘hung hăng tiếp cận’ tàu sân bay USS Abraham L
# Added: Thụy Điển, Đan Mạch cam kết cung cấp hệ thống phòng không cho Ukraine
#
# Summary: 7 added, 3 duplicates, 0 old
# ✓ Added 7 articles from this feed
#
# ================================================================================
# Processing RSS Feed 130/137
# ================================================================================
# Fetching RSS feed: https://kienthuc.net.vn/rss/home.rss
# Found 50 entries in RSS feed
# Added: Kẻ cướp ngân hàng ở Yên Bái bị bắt sau ít phút
# Added: Dự kiến đạt 16 điểm 3 môn thi tốt nghiệp THPT mới được xét học bạ
# Added: Xe tải chạy quá tốc độ đâm loạt xe máy, 5 người tử vong
# Added: Bắt giữ vụ vận chuyển trái phép gỗ quý mán đỉa ở Quảng Trị
# Added: Những đặc sản hút khách tại Hội chợ Mùa Xuân 2026
# Added: Phú Thọ đưa 31 lô đất lên sàn, khởi điểm từ 8 triệu đồng/m²
# Added: Vụ 46 người nghi ngộ độc sau tiệc tất niên, tìm thấy vi khuẩn E. coli
# Added: Bắc Ninh dự kiến nhiều điểm mới trong tuyển sinh năm học 2026 - 2027
# Added: Tai nạn giao thông khiến một CSGT tử vong ở Thái Nguyên
# Added: Lý Nhã Kỳ mang ngựa về resort ở Đồng Nai chụp ảnh đón Tết Bính Ngọ
# Added: Nam sinh 15 tuổi sốt xuất huyết biến chứng tan huyết do thiếu men G6PD
# Added: Vùng 3 Hải quân tổ chức hội thi phần mềm mô phỏng huấn luyện
# Added: Dương Quý Phi qua đời bí ẩn, xuất hiện mộ ở Nhật Bản gây tranh cãi
# Added: Kẻ gây ra hàng loạt vụ cướp giật dây chuyền vàng ở Vĩnh Long 'sa lưới'
# Added: Ngày giờ đẹp cúng tạ đất cuối năm Ất Tỵ 2025 và văn khấn chuẩn phong thủy
#
# Summary: 50 added, 0 duplicates, 0 old
# ✓ Added 50 articles from this feed
#
# ================================================================================
# Processing RSS Feed 131/137
# ================================================================================
# Fetching RSS feed: https://kienthuc.net.vn/rss/nha-khoa-hoc-345.rss
# Found 50 entries in RSS feed
#
# Summary: 0 added, 29 duplicates, 21 old
# ✓ Added 0 articles from this feed
#
# ================================================================================
# Processing RSS Feed 132/137
# ================================================================================
# Fetching RSS feed: https://kienthuc.net.vn/rss/spotlight-379.rss
# Found 50 entries in RSS feed
# Added: Russo-Balt F200 - xe van điện vỏ thép giá 2,2 tỷ, bảo hành 100 năm
# Added: Mỹ Tâm - Mai Tài Phến tiết lộ hậu trường làm việc chung
# Added: Bạn gái hot girl của tiền vệ U23 Việt Nam 'lên đồ' khoe dáng vạn người mê
# Added: Hot face sao Việt: Tóc Tiên khoe tóc mới được khen trẻ trung, dễ thương
# Added: Ngắm ‘nàng thơ du học sinh’ Meichan trong tà áo dài giữa non nước Ninh Bình
# Added: Cận cảnh Volkswagen Teramont Pro sắp về Việt Nam, khoảng 2,3 tỷ đồng
# Added: Sao Việt tề tựu dự tiệc sinh nhật con gái Nhật Kim Anh
# Added: Mitsubishi Việt Nam ưu đãi đặc biệt cho khách mua ôtô tháng 2/2026
# Added: 'Bông hồng lai' Ebra Lê diện áo dài duyên dáng, hòa vào không khí Tết Việt
# Added: TwoZero - xe đạp siêu tiết kiệm điện, khoang lái như tàu vũ trụ
# Added: 'Dâu hào môn' Vân Tiny khoe dáng ngọt ngào với áo bà ba
# Added: Hyundai Creta 2027 lộ diện, thiết kế đột phá lấy cảm hứng từ Nexo
# Added: Việt Bắc gây chú ý dù đảm nhận vai phụ trong Gia đình trái dấu
# Added: Danh tính fan nữ MU xinh đẹp khiến fan 'Quỷ đỏ' xôn xao
# Added: Thị trường ôtô Việt tràn ngập ưu đãi, giảm giá trước Tết Nguyên đán
# Added: Cô giáo tiếng Anh chẳng dạy online vẫn có gần 3 triệu người theo dõi
# Added: "Nữ thần thanh xuân" Chương Nhược Nam nhan sắc lột xác đầy quyến rũ
# Added: Yamaha EC-06 ra mắt - xe máy điện chạy 169km/sạc, giá 48 triệu đồng
# Added: Lê Tú Vi diện áo dài khoe nhan sắc “miễn chê” với gương mặt không tì vết
# Added: Duy Khánh giả gái siêu đỉnh, sự nghiệp ngày càng thăng hoa
# Added: Soi mặt mộc của bạn gái thiếu gia út nhà tỷ phú Johnathan Hạnh Nguyễn
# Added: Vẻ đẹp chín muồi, phong thái ngày càng cuốn hút của Hoa hậu Tiểu Vy
# Added: Bệnh nhân chờ ghép giác mạc bị người vô gia cư hành hung đến mù vĩnh viễn
# Added: Hot TikToker Bò Chảnh thả dáng với áo lụa mềm mại giữa phố người Hoa Sài Gòn
# Added: Diễm My 9x – Thiên Minh chụp ảnh áo dài kỷ niệm tình bạn 17 năm
# Added: Mitsubishi Pajero 2027 sẽ "lột xác" mạnh mẽ, đối đầu Toyota Fortuner
# Added: Jun Vũ ví mình như “đóa bạch trà”, khoe nhan sắc mong manh mà cuốn hút
# Added: Uyển Ân – Pháp Kiều mang sắc xuân đến sớm qua khoảnh khắc dạo chơi đầu năm
# Added: Xe tải mất lái trên đèo Đá Trắng, nhiều phương tiện ngược chiều thoát nạn
# Added: Người dân cứu một phụ nữ và một đứa trẻ khỏi chiếc taxi bị rơi xuống nước
#
# Summary: 30 added, 20 duplicates, 0 old
# ✓ Added 30 articles from this feed
#
# ================================================================================
# Processing RSS Feed 133/137
# ================================================================================
# Fetching RSS feed: https://kienthuc.net.vn/rss/chinh-tri-348.rss
# Found 50 entries in RSS feed
# Added: Thủ tướng chỉ đạo tháo gỡ vướng mắc trong triển khai Nghị định 46
#
# Summary: 1 added, 49 duplicates, 0 old
# ✓ Added 1 articles from this feed
#
# ================================================================================
# Processing RSS Feed 134/137
# ================================================================================
# Fetching RSS feed: https://kienthuc.net.vn/rss/xa-hoi-349.rss
# Found 50 entries in RSS feed
# Added: Đăng tin giả kêu gọi từ thiện, nam thanh niên chiếm đoạt 84 triệu đồng
# Added: CSGT phối hợp bắt giữ 2 thuyền khai thác cát trái phép trên sông Lam
# Added: Đối tượng truy nã đặc biệt 'sa lưới' khi chuẩn bị trốn ra nước ngoài
# Added: Bắt nhanh nhóm đối tượng đột nhập cửa hàng Điện Máy Xanh trộm tài sản
# Added: Cháy dữ dội nhà trọ 8 tầng ở Hà Nội khiến nhiều người hoảng hốt
# Added: Công an vào cuộc vụ chặt phá hơn 1.200 gốc hoa ly cùng nhiều gốc hoa hồng
# Added: Phú Thọ tăng cường quản lý, ngăn chặn khai thác khoáng sản trái phép
# Added: Xử phạt trường hợp đăng tải thông tin kích động bạo lực trên mạng xã hội
# Added: Làm giả con dấu để bán giấy khám sức khoẻ rởm
# Added: Kịp thời giúp cháu bé 3 tuổi đi lạc trở về với gia đình ở Hà Nội
# Added: Tìm nhân chứng vụ tai nạn khiến 1 người chấn thương nặng ở Hà Nội
# Added: Phú Quốc xác minh vụ bảo mẫu đánh trẻ tại trường mầm non Happy Home
# Added: Không khí lạnh dồn dập trước Tết gây mưa nhiều nơi ở Bắc Bộ
#
# Summary: 13 added, 37 duplicates, 0 old
# ✓ Added 13 articles from this feed
#
# ================================================================================
# Processing RSS Feed 135/137
# ================================================================================
# Fetching RSS feed: https://kienthuc.net.vn/rss/the-gioi-350.rss
# Found 50 entries in RSS feed
# Added: Thông tin vụ con trai cố lãnh đạo Libya Moammar Gadhafi bị ám sát
# Added: Chính phủ Mỹ mở cửa trở lại
# Added: Bé trai bơi suốt 4 tiếng trên biển để tìm người cứu mẹ
# Added: Hình ảnh tuyết rơi dày ở Nhật Bản, hàng chục người thiệt mạng
#
# Summary: 4 added, 46 duplicates, 0 old
# ✓ Added 4 articles from this feed
#
# ================================================================================
# Processing RSS Feed 136/137
# ================================================================================
# Fetching RSS feed: https://kienthuc.net.vn/rss/quan-su-359.rss
# Found 50 entries in RSS feed
# Added: Quân đội Nga chiếm Minkivka, áp sát phòng tuyến Slovyansk-Kramatorsk
# Added: Mỹ bắn rơi UAV Iran gần tàu sân bay USS Abraham Lincoln
# Added: Nga sẵn sàng chuyển giao công nghệ Su-57 cho Ấn Độ, hỗ trợ phát triển nội địa
#
# Summary: 3 added, 47 duplicates, 0 old
# ✓ Added 3 articles from this feed
#
# ================================================================================
# Processing RSS Feed 137/137
# ================================================================================
# Fetching RSS feed: https://kienthuc.net.vn/rss/giai-tri-365.rss
# Found 50 entries in RSS feed
# Added: Duyên Quỳnh xin lỗi, tự trách bản thân vì ồn ào hát nhép
#
# Summary: 1 added, 49 duplicates, 0 old
# ✓ Added 1 articles from this feed
#
# ================================================================================
# SUMMARY
# ================================================================================
# Total feeds processed: 137
# Total articles added: 1645
# Output file: rss_feed_articles_v2.csv
# ================================================================================

# %%
# TEST: Kiểm tra cấu trúc RSS feed
import feedparser
import requests

rss_url = "https://rss.app/feeds/b72SnQUmvktz54SH.xml"

try:
    print(f"Fetching RSS feed: {rss_url}")
    feed = feedparser.parse(rss_url)
    
    print(f"\nFeed title: {feed.feed.get('title', 'N/A')}")
    print(f"Feed link: {feed.feed.get('link', 'N/A')}")
    print(f"Total entries: {len(feed.entries)}")
    
    if feed.entries:
        print("\n" + "="*80)
        print("First entry details:")
        print("="*80)
        entry = feed.entries[0]
        
        print(f"\nTitle: {entry.get('title', 'N/A')}")
        print(f"Link: {entry.get('link', 'N/A')}")
        print(f"Published: {entry.get('published', 'N/A')}")
        
        if hasattr(entry, 'published_parsed'):
            print(f"Published parsed: {entry.published_parsed}")
        
        if 'author' in entry:
            print(f"Author: {entry.author}")
        
        if 'tags' in entry and entry.tags:
            print(f"Tags: {[tag.get('term', '') for tag in entry.tags]}")
        
        # Content
        if 'content' in entry:
            content = entry.content[0].get('value', '') if isinstance(entry.content, list) else entry.content
            print(f"\nContent length: {len(content)} chars")
            print(f"Content preview: {content[:300]}...")
        
        if 'summary' in entry:
            print(f"\nSummary length: {len(entry.summary)} chars")
            print(f"Summary preview: {entry.summary[:300]}...")
        
        print("\n" + "="*80)
        print(f"Showing titles of first 10 entries:")
        print("="*80)
        for i, e in enumerate(feed.entries[:10], 1):
            print(f"{i}. {e.get('title', 'No title')[:100]}")
            
except Exception as e:
    print(f"Error: {e}")
    import traceback
    traceback.print_exc()
# Out:
# Fetching RSS feed: https://rss.app/feeds/b72SnQUmvktz54SH.xml
#
# Feed title: Việt Nam - Google Tin tức
# Feed link: https://news.google.com/topics/CAAqIggKIhxDQkFTRHdvSkwyMHZNREZqY21RMUVnSjJhU2dBUAE?hl=vi&gl=VN&ceid=VN%3Avi
# Total entries: 25
#
# ================================================================================
# First entry details:
# ================================================================================
#
# Title: Không có KPI cho người đứng đầu thì có thể 'các anh cứ làm còn tôi đứng chỉ tay'
# Link: https://vietnamnet.vn/khong-co-kpi-cho-nguoi-dung-dau-thi-co-the-cac-anh-cu-lam-con-toi-dung-chi-tay-2487197.html
# Published: Mon, 02 Feb 2026 07:51:00 GMT
# Published parsed: time.struct_time(tm_year=2026, tm_mon=2, tm_mday=2, tm_hour=7, tm_min=51, tm_sec=0, tm_wday=0, tm_yday=33, tm_isdst=0)
# Author: Trần Thường
#
# Summary length: 501 chars
# Summary preview: <div><img src="https://static-images.vnncdn.net/vps_images_publish/000001/000003/2026/2/2/khong-co-kpi-cho-nguoi-dung-dau-thi-co-the-cac-anh-cu-lam-con-toi-dung-chi-tay-1715.jpg?width=0&amp;s=te330VQjU7iFsqDcE7SUwA" style="width: 100%;" /><div>Ông Nguyễn Xuân Thắng cho rằng, trong công việc cần chú ...
#
# ================================================================================
# Showing titles of first 10 entries:
# ================================================================================
# 1. Không có KPI cho người đứng đầu thì có thể 'các anh cứ làm còn tôi đứng chỉ tay'
# 2. Dự báo thời tiết mưa rét, không khí lạnh từ nay đến Tết Âm lịch 2026Dự báo thời tiết ngày mai 3.2 tr
# 3. Kết quả điều tra ban đầu vụ 2 người tử vong sau khi uống rượu ngâm
# 4. Chủ tịch nước Lương Cường chúc Tết nguyên Tổng Bí thư Nông Đức Mạnh
# 5. 23 học sinh bị công an mời làm việc vì ra đường nhảy múa theo tiếng còi xe tải
# 6. Thấy gì từ sức ảnh hưởng của Bộ Công an trong khóa 14? - BBC News Tiếng Việt
# 7. Công an làm rõ thông tin lan truyền về việc hỗ trợ 1 triệu đồng/người dịp Tết
# 8. Tổng Bí thư: Nhân dân là nguồn sức mạnh vô tận của Đảng
# 9. Lắp biểu trưng hình giọt nước ở đài tưởng niệm Covid-19
# 10. Bị rắn độc cắn hôn mê sau khi sát hại vợ

# %%
# Thống kê nguồn tin
import pandas as pd

df = pd.read_csv("rss_feed_articles.csv")

print(f"Tổng số bài viết: {len(df)}")
print(f"\nThống kê theo nguồn:")
print(df['source.name'].value_counts())

print(f"\nThống kê theo ngày:")
df['date'] = pd.to_datetime(df['published_at']).dt.date
print(df['date'].value_counts().sort_index(ascending=False).head(10))

print(f"\nMẫu 3 bài viết:")
print(df[['title', 'source.name', 'published_at']].head(3).to_string(index=False))
# Out:
# Tổng số bài viết: 729
#
# Thống kê theo nguồn:
# source.name
# RSS_Feed                                        504
# Thành Đạt                                        28
# Minh Phương                                      27
# Đức Hoàng                                        25
# Tri Túc                                          21
# Khổng Chiêm                                       9
# Thanh Thương                                      9
# Thảo Thu                                          9
# Toàn Thịnh                                        9
# Mỹ Tâm                                            8
# Thanh Thành                                       8
# Huỳnh Anh                                         8
# Cẩm Hà                                            8
# VnExpress                                         6
# N. Tuấn Sơn                                       5
# Minh Huyền                                        5
# Đăng Khôi                                         4
# Trường Thịnh                                      4
# CTV                                               2
# Văn Hưng                                          2
# Trần Thường                                       2
# Ngọc Tân,Phương Quyên                             1
# Phạm Hữu                                          1
# Ca Linh-Tâm Minh                                  1
# https://www.facebook.com/bbcnews                  1
# QU&#7888;C NAM                                    1
# VietNamNet News                                   1
# laodong.vn                                        1
# THÀNH CHUNG                                       1
# Lã Nghĩa Hiếu                                     1
# Theo Đan Tâm Sức khỏe đời sống                    1
# Nguyệt Phạm                                       1
# Xuân Đoàn                                         1
# Phan Hậu                                          1
# Nguyễn Bình                                       1
# Nguyễn Hoài                                       1
# TTXVN                                             1
# Khoa Nguyễn                                       1
# Trần Thanh                                        1
# Thanh Thương,Tri Túc,Phương Liên                  1
# An Huy                                            1
# Hải Long,Thành Đông,Hướng Dương,Thanh Thương      1
# Hoàng Duật                                        1
# Huân Trần                                         1
# Khổng Chiêm,Tri Túc                               1
# Tiến Thịnh                                        1
# Tri Túc,Thanh Thương                              1
# Name: count, dtype: int64
#
# Thống kê theo ngày:
# date
# 2026-02-02    331
# 2026-02-01    134
# 2026-01-31    107
# 2026-01-30    101
# 2026-01-29     51
# 2026-01-28      4
# Name: count, dtype: int64
#
# Mẫu 3 bài viết:
#                                                                                                                                                                                                                                                                       title      source.name              published_at
#                                                                                                                                                                                            Không có KPI cho người đứng đầu thì có thể 'các anh cứ làm còn tôi đứng chỉ tay'      Trần Thường 2026-02-02T07:51:00+00:00
# Dự báo thời tiết mưa rét, không khí lạnh từ nay đến Tết Âm lịch 2026Dự báo thời tiết ngày mai 3.2 trên cả nướcMiền Bắc sắp đón thêm đợt không khí lạnh mới, trời rét trở lạiDự báo thời tiết 2/2/2026: Miền Bắc rét ngọt, Trung Bộ mưa ràoXem thêm tiêu đề và góc nhìn khác       laodong.vn                       NaN
#                                                                                                                                                                                                          Kết quả điều tra ban đầu vụ 2 người tử vong sau khi uống rượu ngâm Ca Linh-Tâm Minh 2026-02-02T09:21:00+00:00

# %%
# Kiểm tra dữ liệu keywords và category.primary hiện tại
import pandas as pd

df = pd.read_csv("rss_feed_articles.csv")

print("=== KIỂM TRA DỮ LIỆU HIỆN TẠI ===\n")
print(f"1. Keywords:")
print(f"   - Số bài có keywords: {df['keywords'].notna().sum()}/{len(df)}")
print(f"   - Mẫu keywords (nếu có):")
print(df[df['keywords'].notna()]['keywords'].head(3).tolist())

print(f"\n2. Category.primary:")
print(f"   - Số bài có category: {df['category.primary'].notna().sum()}/{len(df)}")
print(f"   - Mẫu category (nếu có):")
print(df[df['category.primary'].notna()]['category.primary'].value_counts().head(10))

print(f"\n3. Phân tích URL để tìm category:")
print("=== PHÂN TÍCH THÔNG TIN CATEGORY/TAGS TỪ RSS FEEDS ===\n")

# Test với 3 RSS feeds khác nhau
test_feeds = [
    ("VnExpress Thời sự", "https://vnexpress.net/rss/thoi-su.rss"),
    ("Dân Trí Xã hội", "https://dantri.com.vn/rss/xa-hoi.rss"),
    ("Thanh Niên Home", "https://thanhnien.vn/rss/home.rss"),
]

for name, url in test_feeds:
    print(f"\n{'='*60}")
    print(f"Feed: {name}")
    print(f"URL: {url}")
    print(f"{'='*60}")
    
    try:
        feed = feedparser.parse(url)
        
        if feed.entries:
            entry = feed.entries[0]
            print(f"\nBài viết mẫu: {entry.get('title', 'N/A')[:80]}...")
            print(f"\nCác trường có sẵn trong entry:")
            
            # Kiểm tra các trường có thể chứa category/tags
            fields_to_check = ['tags', 'categories', 'category', 'keywords', 
                             'dc_subject', 'subjects', 'description']
            
            for field in fields_to_check:
                if field in entry:
                    value = entry[field]
                    print(f"  ✓ {field}: {value}")
            
            # Hiển thị tất cả keys để xem còn gì khác
            print(f"\n  Tất cả keys: {list(entry.keys())}")
            
    except Exception as e:
        print(f"  ✗ Lỗi: {e}")
# Out:
# === PHÂN TÍCH THÔNG TIN CATEGORY/TAGS TỪ RSS FEEDS ===
#
#
# ============================================================
# Feed: VnExpress Thời sự
# URL: https://vnexpress.net/rss/thoi-su.rss
# ============================================================
#
# Bài viết mẫu: Vợ chồng bị phóng điện khi dựng cây nêu ngày Tết...
#
# Các trường có sẵn trong entry:
#   ✓ description: <a href="https://vnexpress.net/vo-chong-bi-phong-dien-khi-dung-cay-neu-ngay-tet-5013260.html"><img src="https://i1-vnexpress.vnecdn.net/2026/02/02/cay-neu-1770031368-1770031378-5033-1770031664.jpg?w=1200&amp;h=0&amp;q=100&amp;dpr=1&amp;fit=crop&amp;s=aIenNgbvud9CbTqrcJBwAg" /></a>Cặp vợ chồng ở xã Nhân Hòa bị phóng điện khi dựng cây nêu tre vướng đường dây 35 kV, người vợ bị bỏng nặng, nguy cơ phải cắt cụt chi.
#
#   Tất cả keys: ['title', 'title_detail', 'summary', 'summary_detail', 'published', 'published_parsed', 'links', 'link', 'id', 'guidislink']
#
# ============================================================
# Feed: Dân Trí Xã hội
# URL: https://dantri.com.vn/rss/xa-hoi.rss
# ============================================================
#
# Bài viết mẫu: Hai vụ cháy trong một buổi chiều ở Nghệ An...
#
# Các trường có sẵn trong entry:
#   ✓ tags: [{'term': 'Thời sự', 'scheme': 'https://dantri.com.vn/thoi-su.htm', 'label': None}]
#   ✓ category: Thời sự
#   ✓ description: <a href="https://dantri.com.vn/thoi-su/hai-vu-chay-trong-mot-buoi-chieu-o-nghe-an-20250907211747289.htm"><img src="https://icdn.dantri.com.vn/2025/09/07/chay-chaykho-hangnghe-anchu-minh-edited-1757254263381.jpg" /></a>(Dân trí) - Hai vụ hỏa hoạn xảy ra cách nhau khoảng gần 3 giờ, may mắn đều không gây thương tích về người.
#
#   Tất cả keys: ['title', 'title_detail', 'published', 'published_parsed', 'links', 'link', 'id', 'guidislink', 'summary', 'summary_detail', 'authors', 'author', 'author_detail', 'tags']
#
# ============================================================
# Feed: Thanh Niên Home
# URL: https://thanhnien.vn/rss/home.rss
# ============================================================
#
# Bài viết mẫu: Nóng: Thái Sơn chốt ngày mổ ở Bệnh viện Vạn Hạnh, chờ tái xuất...
#
# Các trường có sẵn trong entry:
#   ✓ description: <a href="https://thanhnien.vn/nong-thai-son-chot-ngay-mo-o-benh-vien-van-hanh-cho-tai-xuat-185260202214338223.htm"><img src="https://images2.thanhnien.vn/zoom/600_315/528068263637045248/2026/2/2/son-1-1770043710903133777632-0-0-1484-2374-crop-1770043745103772266422.jpg" /></a> Tiền vệ Thái Sơn sẽ được thực hiện ca mổ phẫu thuật điều trị chấn thương dây chằng gặp phải ở trận Ninh Bình gặp CLB CAHN.
#
#   Tất cả keys: ['title', 'title_detail', 'links', 'link', 'summary', 'summary_detail', 'published', 'published_parsed', 'id', 'guidislink']

# %%
# Test trích xuất category và keywords
import re
from urllib.parse import urlparse

def extract_category_from_url(url):
    """Trích xuất category từ URL pattern"""
    
    # Mapping các patterns phổ biến
    category_map = {
        'thoi-su': 'Thời sự',
        'the-gioi': 'Thế giới', 
        'xa-hoi': 'Xã hội',
        'kinh-doanh': 'Kinh doanh',
        'giai-tri': 'Giải trí',
        'the-thao': 'Thể thao',
        'phap-luat': 'Pháp luật',
        'giao-duc': 'Giáo dục',
        'suc-khoe': 'Sức khỏe',
        'gia-dinh': 'Gia đình',
        'du-lich': 'Du lịch',
        'khoa-hoc': 'Khoa học',
        'so-hoa': 'Số hóa',
        'cong-nghe': 'Công nghệ',
        'oto-xe-may': 'Ôtô-Xe máy',
        'doi-song': 'Đời sống',
        'van-hoa': 'Văn hóa',
        'tin-tuc-trong-ngay': 'Tin tức',
        'video': 'Video',
    }
    
    parsed = urlparse(url)
    path_parts = [p for p in parsed.path.split('/') if p]
    
    # Tìm category trong các phần của URL
    for part in path_parts[:2]:  # Chỉ xét 2 phần đầu
        for pattern, category in category_map.items():
            if pattern in part:
                return category
    
    return None

def extract_keywords_from_rss(entry, url):
    """Trích xuất keywords từ RSS entry và URL"""
    keywords = []
    
    # 1. Lấy từ tags RSS (Dân Trí, Tuổi Trẻ)
    if 'tags' in entry:
        for tag in entry['tags']:
            if 'term' in tag and tag['term']:
                keywords.append(tag['term'])
    
    # 2. Lấy từ category field
    if 'category' in entry and entry['category']:
        keywords.append(entry['category'])
    
    # 3. Trích xuất từ URL
    url_category = extract_category_from_url(url)
    if url_category and url_category not in keywords:
        keywords.append(url_category)
    
    return ', '.join(keywords) if keywords else ''

# Test với URLs mẫu
test_urls = [
    "https://vnexpress.net/thoi-su/chinh-tri/bai-viet-123.html",
    "https://dantri.com.vn/the-gioi/my-trung-456.htm",
    "https://thanhnien.vn/kinh-doanh/chung-khoan-789.htm",
    "https://tuoitre.vn/giao-duc/dai-hoc-101.htm",
]

print("=== TEST TRÍCH XUẤT CATEGORY TỪ URL ===\n")
for url in test_urls:
    category = extract_category_from_url(url)
    print(f"URL: {url}")
    print(f"→ Category: {category}\n")
# Out:
# === TEST TRÍCH XUẤT CATEGORY TỪ URL ===
#
# URL: https://vnexpress.net/thoi-su/chinh-tri/bai-viet-123.html
# → Category: Thời sự
#
# URL: https://dantri.com.vn/the-gioi/my-trung-456.htm
# → Category: Thế giới
#
# URL: https://thanhnien.vn/kinh-doanh/chung-khoan-789.htm
# → Category: Kinh doanh
#
# URL: https://tuoitre.vn/giao-duc/dai-hoc-101.htm
# → Category: Giáo dục

# %%
# CẬP NHẬT: Thêm tự động tạo keywords và category vào crawler chính

# Backup file hiện tại
import shutil
shutil.copy("rss_feed_articles.csv", "rss_feed_articles_backup.csv")
print("✓ Đã backup file CSV hiện tại")

# Xóa file cũ để crawl lại với keywords và category
import os
if os.path.exists("rss_feed_articles.csv"):
    os.remove("rss_feed_articles.csv")
print("✓ Đã xóa file cũ, sẵn sàng crawl lại với keywords/category tự động")

print("\n⚠️ LƯU Ý: Bạn cần chạy lại cell #VSC-6bad2b57 với code đã cập nhật")
print("Hoặc tôi có thể tạo một file crawler mới với đầy đủ tính năng.")
# Out:
# ✓ Đã backup file CSV hiện tại
# ✓ Đã xóa file cũ, sẵn sàng crawl lại với keywords/category tự động
#
# ⚠️ LƯU Ý: Bạn cần chạy lại cell #VSC-6bad2b57 với code đã cập nhật
# Hoặc tôi có thể tạo một file crawler mới với đầy đủ tính năng.

# %%
# Kiểm tra kết quả sau khi crawl lại với keywords và category
import pandas as pd

df = pd.read_csv("rss_feed_articles.csv")

print("=" * 80)
print("KẾT QUẢ SAU KHI CẬP NHẬT KEYWORDS VÀ CATEGORY")
print("=" * 80)

print(f"\nTổng số bài viết: {len(df)}")

print(f"\n1. KEYWORDS:")
print(f"   - Số bài có keywords: {df['keywords'].notna().sum()}/{len(df)} ({df['keywords'].notna().sum()/len(df)*100:.1f}%)")
keywords_sample = df[df['keywords'].notna()]['keywords'].head(5)
print(f"   - Mẫu keywords:")
for i, kw in enumerate(keywords_sample, 1):
    print(f"     {i}. {kw[:100]}")

print(f"\n2. CATEGORY.PRIMARY:")
print(f"   - Số bài có category: {df['category.primary'].notna().sum()}/{len(df)} ({df['category.primary'].notna().sum()/len(df)*100:.1f}%)")
print(f"   - Top 10 categories:")
print(df['category.primary'].value_counts().head(10))

print(f"\n3. MẪU 5 BÀI VIẾT:")
sample_df = df[['title', 'category.primary', 'keywords']].head(5)
for idx, row in sample_df.iterrows():
    print(f"\n   [{idx+1}] {row['title'][:60]}...")
    print(f"       Category: {row['category.primary'] if pd.notna(row['category.primary']) else 'N/A'}")
    keywords_str = row['keywords'] if pd.notna(row['keywords']) else 'N/A'
    print(f"       Keywords: {str(keywords_str)[:80]}")
# Out:
# ================================================================================
# KẾT QUẢ SAU KHI CẬP NHẬT KEYWORDS VÀ CATEGORY
# ================================================================================
#
# Tổng số bài viết: 728
#
# 1. KEYWORDS:
#    - Số bài có keywords: 248/728 (34.1%)
#    - Mẫu keywords:
#      1. Du lịch
#      2. Tin tức
#      3. Thời sự
#      4. Thời sự
#      5. Thời sự
#
# 2. CATEGORY.PRIMARY:
#    - Số bài có category: 248/728 (34.1%)
#    - Top 10 categories:
# category.primary
# Thế giới      116
# Kinh doanh    102
# Du lịch         7
# Giải trí        4
# Thời sự         3
# Xã hội          3
# Đời sống        2
# Tin tức         2
# Sức khỏe        2
# Công nghệ       1
# Name: count, dtype: int64
#
# 3. MẪU 5 BÀI VIẾT:
#
#    [1] Việt Nam sẽ giúp Cuba từng bước tự chủ lương thực...
#        Category: N/A
#        Keywords: N/A
#
#    [2] Thủ khoa thi đánh giá tư duy Bách khoa Hà Nội đạt 96,1/100 đ...
#        Category: N/A
#        Keywords: N/A
#
#    [3] Tin mới vụ nhóm du khách nước ngoài bị đuổi đánh ở Nha Trang...
#        Category: N/A
#        Keywords: N/A
#
#    [4] Không có KPI cho người đứng đầu thì có thể 'các anh cứ làm c...
#        Category: N/A
#        Keywords: N/A
#
#    [5] Dự báo thời tiết mưa rét, không khí lạnh từ nay đến Tết Âm l...
#        Category: Du lịch
#        Keywords: Du lịch

# %%
# Phân tích các bài viết không có keywords/category
import pandas as pd

df = pd.read_csv("rss_feed_articles.csv")

# Lấy các bài không có category
no_cat = df[df['category.primary'].isna()]

print(f"Số bài không có category: {len(no_cat)}")
print(f"\nPhân tích nguồn của các bài không có category:")
print(no_cat['source.name'].value_counts().head(10))

print(f"\nMẫu 10 URLs của bài không có category:")
for i, url in enumerate(no_cat['url'].head(10), 1):
    print(f"{i}. {url}")
# Out:
# Số bài không có category: 480
#
# Phân tích nguồn của các bài không có category:
# source.name
# RSS_Feed                            461
# VnExpress                             7
# Trần Thường                           2
# Ca Linh-Tâm Minh                      1
# Znews.vn                              1
# VietNamNet News                       1
# QU&#7888;C NAM                        1
# Lã Nghĩa Hiếu                         1
# https://www.facebook.com/bbcnews      1
# THÀNH CHUNG                           1
# Name: count, dtype: int64
#
# Mẫu 10 URLs của bài không có category:
# 1. https://vnexpress.net/viet-nam-se-giup-cuba-tung-buoc-tu-chu-luong-thuc-5013267.html
# 2. https://vnexpress.net/thu-khoa-thi-danh-gia-tu-duy-bach-khoa-ha-noi-dat-96-1-100-diem-5012894.html
# 3. https://znews.vn/tin-moi-vu-nhom-du-khach-nuoc-ngoai-bi-duoi-danh-o-nha-trang-post1616048.html
# 4. https://vietnamnet.vn/khong-co-kpi-cho-nguoi-dung-dau-thi-co-the-cac-anh-cu-lam-con-toi-dung-chi-tay-2487197.html
# 5. https://nld.com.vn/ket-qua-dieu-tra-ban-dau-vu-2-nguoi-tu-vong-sau-khi-uong-ruou-ngam-196260202160814492.htm
# 6. https://vietnamnet.vn/chu-tich-nuoc-luong-cuong-chuc-tet-nguyen-tong-bi-thu-nong-duc-manh-2487332.html
# 7. https://tuoitre.vn/23-hoc-sinh-bi-cong-an-moi-lam-viec-vi-ra-duong-nhay-mua-theo-tieng-coi-xe-tai-20260202181003099.htm
# 8. https://www.bbc.com/vietnamese/articles/c8xdn7y0pryo
# 9. https://vnexpress.net/tong-bi-thu-nhan-dan-la-nguon-suc-manh-vo-tan-cua-dang-5012844.html
# 10. https://vnexpress.net/lap-bieu-trung-hinh-giot-nuoc-o-dai-tuong-niem-covid-19-5012783.html

# %%
# Test trích xuất category từ các URL thực tế
test_real_urls = [
    "https://vnexpress.net/viet-nam-se-giup-cuba-tung-buoc-tu-chu-luong-thuc-5013267.html",
    "https://vietnamnet.vn/khong-co-kpi-cho-nguoi-dung-dau-thi-co-the-cac-anh-cu-lam-con-toi-dung-chi-tay-2487197.html",
    "https://tuoitre.vn/23-hoc-sinh-bi-cong-an-moi-lam-viec-vi-ra-duong-nhay-mua-theo-tieng-coi-xe-tai-20260202181003099.htm",
    "https://nld.com.vn/ket-qua-dieu-tra-ban-dau-vu-2-nguoi-tu-vong-sau-khi-uong-ruou-ngam-196260202160814492.htm",
]

print("Test trích xuất category từ URLs không có category trong path:\n")
for url in test_real_urls:
    cat = extract_category_from_url(url)
    print(f"{cat or 'NONE':<15} | {url}")
# Out:
# Test trích xuất category từ URLs không có category trong path:
#
# NONE            | https://vnexpress.net/viet-nam-se-giup-cuba-tung-buoc-tu-chu-luong-thuc-5013267.html
# NONE            | https://vietnamnet.vn/khong-co-kpi-cho-nguoi-dung-dau-thi-co-the-cac-anh-cu-lam-con-toi-dung-chi-tay-2487197.html
# NONE            | https://tuoitre.vn/23-hoc-sinh-bi-cong-an-moi-lam-viec-vi-ra-duong-nhay-mua-theo-tieng-coi-xe-tai-20260202181003099.htm
# NONE            | https://nld.com.vn/ket-qua-dieu-tra-ban-dau-vu-2-nguoi-tu-vong-sau-khi-uong-ruou-ngam-196260202160814492.htm

# %%
print("=" * 80)
print("TÓM TẮT KẾT QUẢ")
print("=" * 80)

print("""
✅ ĐÃ HOÀN THÀNH:
1. Tự động trích xuất keywords và category từ RSS feeds
2. Thu thập được 728 bài viết từ 17 RSS feeds
3. Có 248/728 bài (34.1%) đã có keywords và category tự động

📊 KẾT QUẢ CHI TIẾT:
- Keywords: 34.1% bài viết có keywords
- Category: 34.1% bài viết có category
- Top categories: Thế giới (116), Kinh doanh (102), Du lịch (7)

🔍 PHƯƠNG PHÁP TRÍCH XUẤT:
1. Từ RSS tags (Dân Trí, Tuổi Trẻ có sẵn tags)
2. Từ URL pattern (nhận diện /thoi-su/, /the-gioi/, etc.)
3. Ưu tiên: RSS tags > URL category

⚠️ HẠN CHẾ:
- 66% bài viết không có category do:
  + RSS feed Google News không có tags
  + Một số URL không chứa category trong path
  + VnExpress, Thanh Niên không cung cấp tags trong RSS

💡 CẢI THIỆN THÊM (NẾU CẦN):
1. Sử dụng NLP để phân loại tự động từ title/content
2. Trích xuất keywords từ title bằng TF-IDF
3. Fetch metadata từ trang web gốc (trong thẻ <meta>)
4. Training model phân loại category dựa trên nội dung

🎯 KHUYẾN NGHỊ:
- Nếu chỉ cần keywords/category cho phân tích cơ bản: Đã đủ (34% có data)
- Nếu cần 100% bài có category: Cần thêm NLP hoặc fetch metadata từ web
- Có thể filter chỉ lấy bài từ RSS feeds có tags (Dân Trí, Tuổi Trẻ)
""")
# Out:
# ================================================================================
# TÓM TẮT KẾT QUẢ
# ================================================================================
#
# ✅ ĐÃ HOÀN THÀNH:
# 1. Tự động trích xuất keywords và category từ RSS feeds
# 2. Thu thập được 728 bài viết từ 17 RSS feeds
# 3. Có 248/728 bài (34.1%) đã có keywords và category tự động
#
# 📊 KẾT QUẢ CHI TIẾT:
# - Keywords: 34.1% bài viết có keywords
# - Category: 34.1% bài viết có category
# - Top categories: Thế giới (116), Kinh doanh (102), Du lịch (7)
#
# 🔍 PHƯƠNG PHÁP TRÍCH XUẤT:
# 1. Từ RSS tags (Dân Trí, Tuổi Trẻ có sẵn tags)
# 2. Từ URL pattern (nhận diện /thoi-su/, /the-gioi/, etc.)
# 3. Ưu tiên: RSS tags > URL category
#
# ⚠️ HẠN CHẾ:
# - 66% bài viết không có category do:
#   + RSS feed Google News không có tags
#   + Một số URL không chứa category trong path
#   + VnExpress, Thanh Niên không cung cấp tags trong RSS
#
# 💡 CẢI THIỆN THÊM (NẾU CẦN):
# 1. Sử dụng NLP để phân loại tự động từ title/content
# 2. Trích xuất keywords từ title bằng TF-IDF
# 3. Fetch metadata từ trang web gốc (trong thẻ <meta>)
# 4. Training model phân loại category dựa trên nội dung
#
# 🎯 KHUYẾN NGHỊ:
# - Nếu chỉ cần keywords/category cho phân tích cơ bản: Đã đủ (34% có data)
# - Nếu cần 100% bài có category: Cần thêm NLP hoặc fetch metadata từ web
# - Có thể filter chỉ lấy bài từ RSS feeds có tags (Dân Trí, Tuổi Trẻ)

# %%
# Hiển thị danh sách RSS feeds đã cập nhật
print("=" * 80)
print("DANH SÁCH RSS FEEDS ĐÃ CẬP NHẬT")
print("=" * 80)

print(f"\nTổng số feeds: {len(RSS_FEEDS)}")
print("\nPhân loại theo nguồn:")

sources = {}
for feed in RSS_FEEDS:
    if "vnexpress" in feed:
        source = "VnExpress"
    elif "dantri" in feed:
        source = "Dân Trí"
    elif "tuoitre" in feed:
        source = "Tuổi Trẻ"
    elif "thanhnien" in feed:
        source = "Thanh Niên"
    elif "vietnamnet" in feed:
        source = "VietnamNet"
    else:
        source = "Khác"
    
    if source not in sources:
        sources[source] = []
    sources[source].append(feed)

for source, feeds in sources.items():
    print(f"\n{source}: {len(feeds)} feeds")
    for i, feed in enumerate(feeds, 1):
        # Lấy tên category từ URL
        category = feed.split('/')[-1].replace('.rss', '').replace('-', ' ').title()
        print(f"  {i}. {category}")

print("\n" + "=" * 80)
print(f"Sẵn sàng crawl {len(RSS_FEEDS)} RSS feeds!")
print("=" * 80)
# Out:
# ================================================================================
# DANH SÁCH RSS FEEDS ĐÃ CẬP NHẬT
# ================================================================================
#
# Tổng số feeds: 47
#
# Phân loại theo nguồn:
#
# VnExpress: 15 feeds
#   1. Tin Moi Nhat
#   2. Thoi Su
#   3. The Gioi
#   4. Kinh Doanh
#   5. Giai Tri
#   6. The Thao
#   7. Phap Luat
#   8. Giao Duc
#   9. Suc Khoe
#   10. Gia Dinh
#   11. Du Lich
#   12. Khoa Hoc
#   13. So Hoa
#   14. Oto Xe May
#   15. Y Kien
#
# Dân Trí: 10 feeds
#   1. Trang Chu
#   2. Xa Hoi
#   3. The Gioi
#   4. Kinh Doanh
#   5. The Thao
#   6. Giai Tri
#   7. Giao Duc
#   8. Suc Khoe
#   9. Du Lich
#   10. O To Xe May
#
# Tuổi Trẻ: 9 feeds
#   1. Tin Moi Nhat
#   2. Thoi Su
#   3. The Gioi
#   4. Phap Luat
#   5. Kinh Doanh
#   6. Giao Duc
#   7. The Thao
#   8. Giai Tri
#   9. Xe
#
# Thanh Niên: 8 feeds
#   1. Home
#   2. Thoi Su
#   3. The Gioi
#   4. Kinh Te
#   5. Van Hoa
#   6. The Thao
#   7. Cong Nghe
#   8. Gioi Tre
#
# VietnamNet: 5 feeds
#   1. Thoi Su
#   2. The Gioi
#   3. Kinh Doanh
#   4. Giao Duc
#   5. The Thao
#
# ================================================================================
# Sẵn sàng crawl 47 RSS feeds!
# ================================================================================

# %%
# Kiểm tra kết quả sau khi crawl với 47 RSS feeds
import pandas as pd

df = pd.read_csv("rss_feed_articles.csv")

print("=" * 80)
print("KẾT QUẢ CRAWL VỚI 47 RSS FEEDS")
print("=" * 80)

print(f"\nTổng số bài viết: {len(df):,}")

print(f"\n📊 PHÂN BỐ THEO NGUỒN:")
print(df['source.name'].value_counts().head(15))

print(f"\n📅 PHÂN BỐ THEO NGÀY:")
df['date'] = pd.to_datetime(df['published_at']).dt.date
date_dist = df['date'].value_counts().sort_index(ascending=False).head(10)
for date, count in date_dist.items():
    print(f"  {date}: {count:,} bài")

print(f"\n🏷️ KEYWORDS & CATEGORY:")
keywords_count = df['keywords'].notna().sum()
category_count = df['category.primary'].notna().sum()
print(f"  - Số bài có keywords: {keywords_count:,}/{len(df):,} ({keywords_count/len(df)*100:.1f}%)")
print(f"  - Số bài có category: {category_count:,}/{len(df):,} ({category_count/len(df)*100:.1f}%)")

print(f"\n📂 TOP 10 CATEGORIES:")
print(df['category.primary'].value_counts().head(10))

print("\n" + "=" * 80)
print(f"✅ Crawl hoàn tất! File: {CSV_PATH}")
print("=" * 80)
# Out:
# ================================================================================
# KẾT QUẢ CRAWL VỚI 47 RSS FEEDS
# ================================================================================
#
# Tổng số bài viết: 2,073
#
# 📊 PHÂN BỐ THEO NGUỒN:
# source.name
# RSS_Feed        1848
# Thành Đạt         28
# Minh Phương       27
# Đức Hoàng         25
# Tri Túc           21
# Khổng Chiêm        9
# Thảo Thu           9
# Thanh Thương       9
# Toàn Thịnh         9
# Mỹ Tâm             8
# Huỳnh Anh          8
# Thanh Thành        8
# Cẩm Hà             8
# VnExpress          7
# Minh Huyền         5
# Name: count, dtype: int64
#
# 📅 PHÂN BỐ THEO NGÀY:
#   2026-02-02: 591 bài
#   2026-02-01: 466 bài
#   2026-01-31: 373 bài
#   2026-01-30: 351 bài
#   2026-01-29: 251 bài
#   2026-01-28: 40 bài
#
# 🏷️ KEYWORDS & CATEGORY:
#   - Số bài có keywords: 321/2,073 (15.5%)
#   - Số bài có category: 321/2,073 (15.5%)
#
# 📂 TOP 10 CATEGORIES:
# category.primary
# Thế giới      131
# Kinh doanh    107
# Du lịch        17
# Giáo dục        7
# Khoa học        7
# Xã hội          7
# Video           7
# Gia đình        6
# Văn hóa         5
# Công nghệ       5
# Name: count, dtype: int64
#
# ================================================================================
# ✅ Crawl hoàn tất! File: rss_feed_articles.csv
# ================================================================================

# %%
# Hiển thị danh sách RSS feeds sau khi cập nhật
print("=" * 80)
print("DANH SÁCH RSS FEEDS SAU KHI CẬP NHẬT")
print("=" * 80)

print(f"\nTổng số feeds: {len(RSS_FEEDS)}")
print("\nPhân loại theo nguồn:")

sources = {}
for feed in RSS_FEEDS:
    if "vnexpress" in feed:
        source = "VnExpress"
    elif "dantri" in feed:
        source = "Dân Trí"
    elif "tuoitre" in feed:
        source = "Tuổi Trẻ"
    elif "thanhnien" in feed:
        source = "Thanh Niên"
    elif "vietnamnet" in feed:
        source = "VietnamNet"
    elif "laodong" in feed:
        source = "Lao Động"
    elif "nld.com.vn" in feed:
        source = "Người Lao Động"
    elif "vietnamplus" in feed:
        source = "VietnamPlus"
    elif "soha" in feed:
        source = "Soha"
    else:
        source = "Khác"
    
    if source not in sources:
        sources[source] = []
    sources[source].append(feed)

for source, feeds in sorted(sources.items()):
    print(f"\n{source}: {len(feeds)} feeds")

print("\n" + "=" * 80)
print(f"✅ Tổng cộng {len(RSS_FEEDS)} RSS feeds từ {len(sources)} nguồn tin!")
print("=" * 80)

print("\nLưu ý: ZNews URLs bạn cung cấp là trang HTML, không phải RSS.")
print("Nếu cần crawl ZNews, có thể cần phương pháp khác (HTML parsing).")
# Out:
# ================================================================================
# DANH SÁCH RSS FEEDS SAU KHI CẬP NHẬT
# ================================================================================
#
# Tổng số feeds: 103
#
# Phân loại theo nguồn:
#
# Dân Trí: 10 feeds
#
# Lao Động: 11 feeds
#
# Người Lao Động: 17 feeds
#
# Soha: 9 feeds
#
# Thanh Niên: 8 feeds
#
# Tuổi Trẻ: 9 feeds
#
# VietnamNet: 5 feeds
#
# VietnamPlus: 19 feeds
#
# VnExpress: 15 feeds
#
# ================================================================================
# ✅ Tổng cộng 103 RSS feeds từ 9 nguồn tin!
# ================================================================================
#
# Lưu ý: ZNews URLs bạn cung cấp là trang HTML, không phải RSS.
# Nếu cần crawl ZNews, có thể cần phương pháp khác (HTML parsing).

# %%
# Kiểm tra kết quả cuối cùng
import pandas as pd

df = pd.read_csv("rss_feed_articles.csv")

print("=" * 80)
print("KẾT QUẢ CRAWL VỚI 103 RSS FEEDS")
print("=" * 80)

print(f"\n📊 TỔNG QUAN:")
print(f"   - Tổng số bài viết: {len(df):,}")
print(f"   - Số feeds: 103 (từ 9 nguồn tin)")

print(f"\n📰 PHÂN BỐ THEO NGUỒN (Top 15):")
source_dist = df['source.name'].value_counts().head(15)
for source, count in source_dist.items():
    print(f"   {source:<25} {count:>5,} bài")

print(f"\n📅 PHÂN BỐ THEO NGÀY:")
df['date'] = pd.to_datetime(df['published_at']).dt.date
date_dist = df['date'].value_counts().sort_index(ascending=False).head(7)
for date, count in date_dist.items():
    print(f"   {date}: {count:>4,} bài")

print(f"\n🏷️ KEYWORDS & CATEGORY:")
keywords_count = df['keywords'].notna().sum()
category_count = df['category.primary'].notna().sum()
print(f"   - Số bài có keywords: {keywords_count:,}/{len(df):,} ({keywords_count/len(df)*100:.1f}%)")
print(f"   - Số bài có category: {category_count:,}/{len(df):,} ({category_count/len(df)*100:.1f}%)")

print(f"\n📂 TOP 15 CATEGORIES:")
cat_dist = df['category.primary'].value_counts().head(15)
for cat, count in cat_dist.items():
    print(f"   {cat:<20} {count:>4,} bài")

# Tính độ phủ dữ liệu
avg_content_length = df['content.text'].str.len().mean()
print(f"\n📝 CHẤT LƯỢNG DỮ LIỆU:")
print(f"   - Độ dài trung bình content: {avg_content_length:,.0f} ký tự")
print(f"   - Số bài có content: {df['content.text'].notna().sum():,}/{len(df):,}")

print("\n" + "=" * 80)
print(f"✅ HOÀN TẤT! File: rss_feed_articles.csv")
print(f"   Dung lượng: {os.path.getsize('rss_feed_articles.csv') / 1024 / 1024:.2f} MB")
print("=" * 80)
# Out:
# ================================================================================
# KẾT QUẢ CRAWL VỚI 103 RSS FEEDS
# ================================================================================
#
# 📊 TỔNG QUAN:
#    - Tổng số bài viết: 3,386
#    - Số feeds: 103 (từ 9 nguồn tin)
#
# 📰 PHÂN BỐ THEO NGUỒN (Top 15):
#    RSS_Feed                  3,161 bài
#    Thành Đạt                    28 bài
#    Minh Phương                  27 bài
#    Đức Hoàng                    25 bài
#    Tri Túc                      21 bài
#    Khổng Chiêm                   9 bài
#    Thảo Thu                      9 bài
#    Thanh Thương                  9 bài
#    Toàn Thịnh                    9 bài
#    Mỹ Tâm                        8 bài
#    Huỳnh Anh                     8 bài
#    Thanh Thành                   8 bài
#    Cẩm Hà                        8 bài
#    VnExpress                     7 bài
#    Minh Huyền                    5 bài
#
# 📅 PHÂN BỐ THEO NGÀY:
#    2026-02-02: 1,103 bài
#    2026-02-01:  726 bài
#    2026-01-31:  551 bài
#    2026-01-30:  540 bài
#    2026-01-29:  406 bài
#    2026-01-28:   59 bài
#
# 🏷️ KEYWORDS & CATEGORY:
#    - Số bài có keywords: 856/3,386 (25.3%)
#    - Số bài có category: 856/3,386 (25.3%)
#
# 📂 TOP 15 CATEGORIES:
#    Thế giới              170 bài
#    Kinh doanh            130 bài
#    Podcast Tin nóng       50 bài
#    Châu Âu                39 bài
#    Kinh tế                36 bài
#    Xã hội                 36 bài
#    Pháp luật              34 bài
#    Châu Mỹ                34 bài
#    Chính trị              29 bài
#    Giao thông             28 bài
#    Giáo dục               25 bài
#    Thể thao               25 bài
#    Đời sống               24 bài
#    Tài chính              23 bài
#    Du lịch                23 bài
#
# 📝 CHẤT LƯỢNG DỮ LIỆU:
#    - Độ dài trung bình content: 1,243 ký tự
#    - Số bài có content: 3,383/3,386
#
# ================================================================================
# ✅ HOÀN TẤT! File: rss_feed_articles.csv
#    Dung lượng: 6.12 MB
# ================================================================================

# %%
# Hiển thị danh sách RSS feeds mới nhất
print("=" * 80)
print("DANH SÁCH RSS FEEDS MỚI NHẤT")
print("=" * 80)

print(f"\nTổng số feeds: {len(RSS_FEEDS)}")
print("\nPhân loại theo nguồn:")

sources = {}
for feed in RSS_FEEDS:
    if "vnexpress" in feed:
        source = "VnExpress"
    elif "dantri" in feed:
        source = "Dân Trí"
    elif "tuoitre" in feed:
        source = "Tuổi Trẻ"
    elif "thanhnien" in feed:
        source = "Thanh Niên"
    elif "vietnamnet" in feed:
        source = "VietnamNet"
    elif "laodong" in feed:
        source = "Lao Động"
    elif "nld.com.vn" in feed:
        source = "Người Lao Động"
    elif "vietnamplus" in feed:
        source = "VietnamPlus"
    elif "soha" in feed:
        source = "Soha"
    elif "nhandan" in feed:
        source = "Nhân Dân"
    elif "baotintuc" in feed:
        source = "Báo Tin Tức"
    elif "kienthuc" in feed:
        source = "Kiến Thức"
    else:
        source = "Khác"
    
    if source not in sources:
        sources[source] = []
    sources[source].append(feed)

for source, feeds in sorted(sources.items()):
    print(f"  {source:<20} {len(feeds):>3} feeds")

print("\n" + "=" * 80)
print(f"🎯 Tổng cộng {len(RSS_FEEDS)} RSS feeds từ {len(sources)} nguồn tin lớn!")
print("=" * 80)
# Out:
# ================================================================================
# DANH SÁCH RSS FEEDS MỚI NHẤT
# ================================================================================
#
# Tổng số feeds: 137
#
# Phân loại theo nguồn:
#   Báo Tin Tức           10 feeds
#   Dân Trí               10 feeds
#   Kiến Thức              8 feeds
#   Lao Động              11 feeds
#   Người Lao Động        17 feeds
#   Nhân Dân              16 feeds
#   Soha                   9 feeds
#   Thanh Niên             8 feeds
#   Tuổi Trẻ               9 feeds
#   VietnamNet             5 feeds
#   VietnamPlus           19 feeds
#   VnExpress             15 feeds
#
# ================================================================================
# 🎯 Tổng cộng 137 RSS feeds từ 12 nguồn tin lớn!
# ================================================================================

# %%
# Kiểm tra kết quả sau khi crawl 137 RSS feeds
import pandas as pd

df = pd.read_csv("rss_feed_articles.csv")

print("=" * 80)
print("KẾT QUẢ CRAWL VỚI 137 RSS FEEDS")
print("=" * 80)

print(f"\n📊 TỔNG QUAN:")
print(f"   - Tổng số bài viết: {len(df):,}")
print(f"   - Số feeds: 137 (từ 12 nguồn tin)")
print(f"   - Tăng từ 3,386 → {len(df):,} bài ({(len(df)-3386)/3386*100:+.1f}%)")

print(f"\n📰 PHÂN BỐ THEO NGUỒN (Top 20):")
source_dist = df['source.name'].value_counts().head(20)
for source, count in source_dist.items():
    print(f"   {source:<30} {count:>5,} bài")

print(f"\n📅 PHÂN BỐ THEO NGÀY:")
df['date'] = pd.to_datetime(df['published_at']).dt.date
date_dist = df['date'].value_counts().sort_index(ascending=False).head(7)
for date, count in date_dist.items():
    print(f"   {date}: {count:>4,} bài")

print(f"\n🏷️ KEYWORDS & CATEGORY:")
keywords_count = df['keywords'].notna().sum()
category_count = df['category.primary'].notna().sum()
print(f"   - Số bài có keywords: {keywords_count:,}/{len(df):,} ({keywords_count/len(df)*100:.1f}%)")
print(f"   - Số bài có category: {category_count:,}/{len(df):,} ({category_count/len(df)*100:.1f}%)")

print(f"\n📂 TOP 20 CATEGORIES:")
cat_dist = df['category.primary'].value_counts().head(20)
for cat, count in cat_dist.items():
    print(f"   {cat:<25} {count:>4,} bài")

# Tính độ phủ dữ liệu
avg_content_length = df['content.text'].str.len().mean()
print(f"\n📝 CHẤT LƯỢNG DỮ LIỆU:")
print(f"   - Độ dài trung bình content: {avg_content_length:,.0f} ký tự")
print(f"   - Số bài có content: {df['content.text'].notna().sum():,}/{len(df):,}")

print("\n" + "=" * 80)
print(f"✅ HOÀN TẤT! File: rss_feed_articles.csv")
file_size_mb = os.path.getsize('rss_feed_articles.csv') / 1024 / 1024
print(f"   Dung lượng: {file_size_mb:.2f} MB")
print(f"   Nguồn tin: 12 tờ báo lớn nhất Việt Nam")
print("=" * 80)
# Out:
# ================================================================================
# KẾT QUẢ CRAWL VỚI 137 RSS FEEDS
# ================================================================================
#
# 📊 TỔNG QUAN:
#    - Tổng số bài viết: 4,027
#    - Số feeds: 137 (từ 12 nguồn tin)
#    - Tăng từ 3,386 → 4,027 bài (+18.9%)
#
# 📰 PHÂN BỐ THEO NGUỒN (Top 20):
#    RSS_Feed                       3,802 bài
#    Thành Đạt                         28 bài
#    Minh Phương                       27 bài
#    Đức Hoàng                         25 bài
#    Tri Túc                           21 bài
#    Khổng Chiêm                        9 bài
#    Thảo Thu                           9 bài
#    Thanh Thương                       9 bài
#    Toàn Thịnh                         9 bài
#    Mỹ Tâm                             8 bài
#    Huỳnh Anh                          8 bài
#    Thanh Thành                        8 bài
#    Cẩm Hà                             8 bài
#    VnExpress                          7 bài
#    Minh Huyền                         5 bài
#    N. Tuấn Sơn                        5 bài
#    Trường Thịnh                       4 bài
#    Đăng Khôi                          4 bài
#    Trần Thường                        2 bài
#    CTV                                2 bài
#
# 📅 PHÂN BỐ THEO NGÀY:
#    2026-02-02: 1,328 bài
#    2026-02-01:  816 bài
#    2026-01-31:  642 bài
#    2026-01-30:  607 bài
#    2026-01-29:  480 bài
#    2026-01-28:   61 bài
#
# 🏷️ KEYWORDS & CATEGORY:
#    - Số bài có keywords: 1,455/4,027 (36.1%)
#    - Số bài có category: 1,455/4,027 (36.1%)
#
# 📂 TOP 20 CATEGORIES:
#    Thế giới                   259 bài
#    Kinh tế                    132 bài
#    Kinh doanh                 130 bài
#    Chính trị                  106 bài
#    Xã hội                      79 bài
#    Quân sự                     76 bài
#    Pháp luật                   71 bài
#    Podcast Tin nóng            50 bài
#    Châu Âu                     47 bài
#    SPOTLIGHT                   46 bài
#    Du lịch                     40 bài
#    Châu Mỹ                     38 bài
#    Thể thao                    38 bài
#    Giáo dục                    35 bài
#    Giải trí                    34 bài
#    Giao thông                  28 bài
#    Châu Á-TBD                  26 bài
#    ASEAN                       25 bài
#    Đời sống                    24 bài
#    Tài chính                   23 bài
#
# 📝 CHẤT LƯỢNG DỮ LIỆU:
#    - Độ dài trung bình content: 1,197 ký tự
#    - Số bài có content: 4,024/4,027
#
# ================================================================================
# ✅ HOÀN TẤT! File: rss_feed_articles.csv
#    Dung lượng: 7.06 MB
#    Nguồn tin: 12 tờ báo lớn nhất Việt Nam
# ================================================================================
